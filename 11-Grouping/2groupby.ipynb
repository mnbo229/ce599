# %% [markdown]
# # Grouping
#
# Chapter 9 in Python for Data Analysis demonstrates a variety of methods to analyze data via data aggregation and grouping operations. Those are the focus of this session.  Our overall goal for this session is to do Exploratory Data Analysis, which is essentially looking at and probing our data to learn about the patterns we can discover in them.  Often this can generate a better understanding of problems in the data, as well as revealing relationships that might be worth exploring in more depth.

# %% [markdown]
# For this exercise, we will use 2010 US Census data, for all census tracts in Kentucky.  A good starting point for any kind of Census data is the American Fact Finder:
#
# https://factfinder.census.gov/faces/nav/jsf/pages/index.xhtml
#
# The Census Bureau produces several products, the most famous of which is the decennial census, which as its name implies, is a true Census.  There are a limited number of data fields for the whole population (or at least those that the Census workers are able to reach, which is pretty good).  The Census has other products that are surveys, such as the American Community Survey (ACS) which asks more detailed questions on an annual basis from a 1% sample of households.
#
# In this case, we are working with file DP-1: Profile of General Population and Housing Characteristics: 2010, which is also a part of something called Summary File 1 (SF-1).  It is for the 100% sample.  A data dictionary for selected fields is below.

# %% [raw]
# P1. POPULATION [1]
# Total: P1-D001
#
# P3. RACE [8]
# Universe: Total population
# Total: P3-D001
# White alone P3-D002
# Black or African American alone P3-D003
# American Indian and Alaska Native alone P3-D004
# Asian alone P3-D005
# Native Hawaiian and Other Pacific Islander alone P3-D006
# Some Other Race alone P3-D007
# Two or More Races P3-D008
#
# P4. HISPANIC OR LATINO ORIGIN [3]
# Universe: Total population
# Total: P4-D001
# Not Hispanic or Latino P4-D002
# Hispanic or Latino P4-D003
#
# H1. HOUSING UNITS [1]
# Universe: Housing units
# Total H1-D001
#
# H3. OCCUPANCY STATUS [3]
# Universe: Housing units
# Total: H3-D001
# Occupied H3-D002
# Vacant H3-D003
#
# H4. TENURE [4]
# Universe: Occupied housing units
# Total: H4-D001
# Owned with a mortgage or a loan H4-D002
# Owned free and clear H4-D003
# Renter-occupied H4-D004
#
# H5. VACANCY STATUS [8]
# Universe: Vacant housing units
# Total: H0050001
# For rent H0050002
# Rented, not occupied H0050003
# For sale only H0050004
# Sold, not occupied H0050005
# For seasonal, recreational, or occasional use H0050006
# For migrant workers H0050007
# Other vacant H0050008

# %%
import pandas as pd

# skip the second row, which contains descriptions
sf1 = pd.read_csv('data/DEC_10_SF1_combined.csv', skiprows=[1])

# make the tract, county and state separate
sf1['tract'] = sf1['GEO.display-label'].apply(lambda x: x.split(sep=',')[0])
sf1['county'] = sf1['GEO.display-label'].apply(lambda x: x.split(sep=',')[1])
sf1['state'] = sf1['GEO.display-label'].apply(lambda x: x.split(sep=',')[2])

# compute some derived fields
sf1['pct_rent'] = sf1['H4-D004'] / sf1['H4-D001'] * 100
sf1['pct_black'] = sf1['P3-D003'] / sf1['P3-D001'] * 100
sf1['pct_asian'] = sf1['P3-D005'] / sf1['P3-D001'] * 100
sf1['pct_white'] = sf1['P3-D002'] / sf1['P3-D001'] * 100
sf1['pct_hisp'] = sf1['P4-D003'] / sf1['P4-D001'] * 100
sf1['pct_vacant'] = sf1['H5-D001'] / sf1['H1-D001'] * 100
sf1[:8]
# Out:
#                  GEO.id      GEO.id2  \
# 0  1400000US21001970100  21001970100
# 1  1400000US21001970200  21001970200
# 2  1400000US21001970300  21001970300
# 3  1400000US21001970401  21001970401
# 4  1400000US21001970402  21001970402
# 5  1400000US21001970500  21001970500
# 6  1400000US21001970600  21001970600
# 7  1400000US21003920100  21003920100
#
#                               GEO.display-label  P1-D001  P3-D001  P3-D002  \
# 0     Census Tract 9701, Adair County, Kentucky     1727     1727     1683
# 1     Census Tract 9702, Adair County, Kentucky     1722     1722     1635
# 2     Census Tract 9703, Adair County, Kentucky     3016     3016     2944
# 3  Census Tract 9704.01, Adair County, Kentucky     4070     4070     3716
# 4  Census Tract 9704.02, Adair County, Kentucky     4261     4261     3950
# 5     Census Tract 9705, Adair County, Kentucky     2457     2457     2402
# 6     Census Tract 9706, Adair County, Kentucky     1403     1403     1366
# 7     Census Tract 9201, Allen County, Kentucky     3185     3185     3114
#
#    P3-D003  P3-D004  P3-D005  P3-D006  ...  H5-D008                 tract  \
# 0       14        1        0        1  ...       60     Census Tract 9701
# 1       41        5        0        0  ...       35     Census Tract 9702
# 2        6       11        8        0  ...      106     Census Tract 9703
# 3      237        1       16        1  ...      109  Census Tract 9704.01
# 4      180       16       16        3  ...       70  Census Tract 9704.02
# 5       16        2        5        0  ...      104     Census Tract 9705
# 6        9        0        0        0  ...       54     Census Tract 9706
# 7       16        8        4        0  ...       96     Census Tract 9201
#
#           county      state   pct_rent  pct_black  pct_asian  pct_white  \
# 0   Adair County   Kentucky  17.411402   0.810654   0.000000  97.452229
# 1   Adair County   Kentucky  19.252874   2.380952   0.000000  94.947735
# 2   Adair County   Kentucky  20.521173   0.198939   0.265252  97.612732
# 3   Adair County   Kentucky  37.215909   5.823096   0.393120  91.302211
# 4   Adair County   Kentucky  30.911681   4.224360   0.375499  92.701244
# 5   Adair County   Kentucky  17.972832   0.651201   0.203500  97.761498
# 6   Adair County   Kentucky  16.920474   0.641483   0.000000  97.362794
# 7   Allen County   Kentucky  15.139752   0.502355   0.125589  97.770801
#
#    pct_hisp  pct_vacant
# 0  2.142444   16.794872
# 1  2.613240   25.161290
# 2  1.856764   15.193370
# 3  1.547912   10.795743
# 4  1.900962   11.642542
# 5  0.773301   17.641997
# 6  1.282965   13.848397
# 7  1.098901   27.559055
#
# [8 rows x 40 columns]

# %% [markdown]
# ## Groupby and Aggregation Operations
#
# Groupby is a powerful method in pandas that follows the split-apply-combine approach to data.  As shown in Figure 9-1 in the context of a sum operation, the data is first split into groups that share the same key values.  Then an operation, in this case a sum, is applied to each group.  Then the results are combined.
#
# The built-in aggregation methods available for groupby operations include:
# * count
# * sum
# * mean
# * median
# * std, var
# * min, max
# * first, last
#
# You can also apply your own functions as aggregation methods.
#
# ![Groupby Operations](groupby.png "Groupby")

# %% [markdown]
# Let's apply this approach to computing total population in each county in our dataset.  We can do this in two steps to help explain what is happening.  First we create a groupby object, using county codes to group all the census blocks in sf1 into groups that share the same county code.

# %%
grouped = sf1['P1-D001'].groupby(sf1['county'])
grouped

# %% [markdown]
# Now that we have this grouping object that represents the **split** part of the workflow in the figure above, we can **apply** operations and **combine** the results using methods like sum:

# %%
grouped.sum()
# Out:
# county
#  Adair County       18656
#  Allen County       19956
#  Anderson County    21421
#  Ballard County      8249
#  Barren County      42173
#                     ...
#  Wayne County       20813
#  Webster County     13621
#  Whitley County     35637
#  Wolfe County        7355
#  Woodford County    24939
# Name: P1-D001, Length: 120, dtype: int64

# %% [markdown]
# We might want to capture the result in a DataFrame if we want to use it in other processing, like merging the results to the original DataFrame.

# %%
county_pop = sf1['P1-D001'].groupby(sf1['county']).sum().to_frame(name='county_population')
county_pop
# Out:
#                   county_population
# county
#  Adair County                 18656
#  Allen County                 19956
#  Anderson County              21421
#  Ballard County                8249
#  Barren County                42173
# ...                             ...
#  Wayne County                 20813
#  Webster County               13621
#  Whitley County               35637
#  Wolfe County                  7355
#  Woodford County              24939
#
# [120 rows x 1 columns]

# %% [markdown]
# Here we merge the county total population with sf1 and create a new DataFrame.

# %%
sf2 = pd.merge(sf1,county_pop, left_on='county', right_index=True)
sf2[:5]
# Out:
#                  GEO.id      GEO.id2  \
# 0  1400000US21001970100  21001970100
# 1  1400000US21001970200  21001970200
# 2  1400000US21001970300  21001970300
# 3  1400000US21001970401  21001970401
# 4  1400000US21001970402  21001970402
#
#                               GEO.display-label  P1-D001  P3-D001  P3-D002  \
# 0     Census Tract 9701, Adair County, Kentucky     1727     1727     1683
# 1     Census Tract 9702, Adair County, Kentucky     1722     1722     1635
# 2     Census Tract 9703, Adair County, Kentucky     3016     3016     2944
# 3  Census Tract 9704.01, Adair County, Kentucky     4070     4070     3716
# 4  Census Tract 9704.02, Adair County, Kentucky     4261     4261     3950
#
#    P3-D003  P3-D004  P3-D005  P3-D006  ...                 tract  \
# 0       14        1        0        1  ...     Census Tract 9701
# 1       41        5        0        0  ...     Census Tract 9702
# 2        6       11        8        0  ...     Census Tract 9703
# 3      237        1       16        1  ...  Census Tract 9704.01
# 4      180       16       16        3  ...  Census Tract 9704.02
#
#           county      state   pct_rent  pct_black  pct_asian  pct_white  \
# 0   Adair County   Kentucky  17.411402   0.810654   0.000000  97.452229
# 1   Adair County   Kentucky  19.252874   2.380952   0.000000  94.947735
# 2   Adair County   Kentucky  20.521173   0.198939   0.265252  97.612732
# 3   Adair County   Kentucky  37.215909   5.823096   0.393120  91.302211
# 4   Adair County   Kentucky  30.911681   4.224360   0.375499  92.701244
#
#    pct_hisp  pct_vacant  county_population
# 0  2.142444   16.794872              18656
# 1  2.613240   25.161290              18656
# 2  1.856764   15.193370              18656
# 3  1.547912   10.795743              18656
# 4  1.900962   11.642542              18656
#
# [5 rows x 41 columns]

# %% [markdown]
# ## Transforming Data with Groupby
#
# In some cases you may want to apply a function to your data, by group.  An example would be to normalize a column by a mean of each group.  Say we wanted to subtract the mean population density of each county from the population density of each census block. We could write a function to subtract the mean from each value, and then use the transform operation to apply this to each group:

# %%
def demean(arr):
    return arr - arr.mean()

# %% [markdown]
# Now we can apply this tranformation to columns in our dataframe.  As examples, let's 'demean' the pct_black and pct_rent columns, subtracting the county-wide mean of these values from the tract-specific values, so that the result is transformed to have a mean of zero within each county.
#
# To check the results, we print the means per county, then the original values for the first 5 rows, then the transformed results.  The transformed results we should be able to calculate by subtracting the appropriate county mean from the tract value.

# %%
normalized = sf1[['pct_black', 'pct_rent']].groupby(sf1['county']).transform(demean)
print(sf1[['pct_black', 'pct_rent']].groupby(sf1['county']).mean())
print(sf1[['county','pct_black', 'pct_rent']][:5])
print(normalized[:5])
# Out:
#                   pct_black   pct_rent
# county
#  Adair County      2.104384  22.886621
#  Allen County      0.716792  22.312658
#  Anderson County   1.419188  20.908477
#  Ballard County    2.690326  21.350937
#  Barren County     3.385357  29.982273
# ...                     ...        ...
#  Wayne County      1.288175  25.683905
#  Webster County    3.825768  22.732870
#  Whitley County    0.519283  31.299399
#  Wolfe County      0.131572  27.972188
#  Woodford County   4.802279  29.615644
#
# [120 rows x 2 columns]
#           county  pct_black   pct_rent
# 0   Adair County   0.810654  17.411402
# 1   Adair County   2.380952  19.252874
# 2   Adair County   0.198939  20.521173
# 3   Adair County   5.823096  37.215909
# 4   Adair County   4.224360  30.911681
#    pct_black   pct_rent
# 0  -1.293729  -5.475218
# 1   0.276569  -3.633747
# 2  -1.905445  -2.365448
# 3   3.718712  14.329289
# 4   2.119977   8.025060

# %% [markdown]
# We can merge these transformed results on to the original DataFrame, and check the means of the original variables and the tranformed ones.  The transformed ones should be arbitrarily close to zero.

# %%
sf2 = pd.merge(sf1,normalized, left_index=True, right_index=True)

sf2.groupby('county')[['pct_black_x', 'pct_black_y', 'pct_rent_x', 'pct_rent_y']].mean()
# Out:
#                   pct_black_x   pct_black_y  pct_rent_x    pct_rent_y
# county
#  Adair County        2.104384 -2.854859e-16   22.886621 -2.030122e-15
#  Allen County        0.716792 -5.551115e-17   22.312658 -3.256654e-15
#  Anderson County     1.419188  8.881784e-17   20.908477  7.105427e-16
#  Ballard County      2.690326  1.480297e-16   21.350937  0.000000e+00
#  Barren County       3.385357  0.000000e+00   29.982273  4.618528e-15
# ...                       ...           ...         ...           ...
#  Wayne County        1.288175 -4.440892e-17   25.683905  7.105427e-16
#  Webster County      3.825768  0.000000e+00   22.732870  0.000000e+00
#  Whitley County      0.519283 -2.775558e-17   31.299399 -8.881784e-16
#  Wolfe County        0.131572  6.938894e-18   27.972188  0.000000e+00
#  Woodford County     4.802279 -6.106227e-16   29.615644 -2.442491e-15
#
# [120 rows x 4 columns]

# %% [markdown]
# Apply is a method we have learned previously, which allows us to apply a function to each row in a DataFrame.  We can also combine apply with groupby to apply functions based on group membership.  For example, the function 'top' sorts an array and selects the top n rows from it.  We provide some defaults for the arguments of how many rows, and the column to use for the selection:

# %%
def top(df, n=5, column='pct_rent'):
    return df.sort_values(by=column, ascending=False).head(n)

# %% [markdown]
# Using this on the full dataset and setting the number of rows and the column to get the top values for, in this case using pct_rent to override the default argument, we get the top 10 tracts in the region in terms of percentage rental.

# %%
top(sf1, n=10, column='pct_rent')
# Out:
#                    GEO.id      GEO.id2  \
# 255  1400000US21061980100  21061980100
# 508  1400000US21111003000  21111003000
# 200  1400000US21047201501  21047201501
# 415  1400000US21093000202  21093000202
# 872  1400000US21163970200  21163970200
# 201  1400000US21047201502  21047201502
# 414  1400000US21093000201  21093000201
# 833  1400000US21151010500  21151010500
# 270  1400000US21067000801  21067000801
# 142  1400000US21037050100  21037050100
#
#                                     GEO.display-label  P1-D001  P3-D001  \
# 255      Census Tract 9801, Edmonson County, Kentucky        8        8
# 508       Census Tract 30, Jefferson County, Kentucky     3565     3565
# 200  Census Tract 2015.01, Christian County, Kentucky     5315     5315
# 415        Census Tract 2.02, Hardin County, Kentucky     4514     4514
# 872         Census Tract 9702, Meade County, Kentucky     2683     2683
# 201  Census Tract 2015.02, Christian County, Kentucky     4527     4527
# 414        Census Tract 2.01, Hardin County, Kentucky     1409     1409
# 833        Census Tract 105, Madison County, Kentucky     4182     4182
# 270       Census Tract 8.01, Fayette County, Kentucky     4094     4094
# 142       Census Tract 501, Campbell County, Kentucky     1733     1733
#
#      P3-D002  P3-D003  P3-D004  P3-D005  P3-D006  ...  H5-D008  \
# 255        8        0        0        0        0  ...        0
# 508      258     3187       15        1       16  ...        7
# 200     3580      982       64       47       81  ...        8
# 415     3053      863       45       78       20  ...       21
# 872     1916      414       41       30       15  ...      161
# 201     3055      740       45       61       84  ...        6
# 414     1150      153        9       19        6  ...       60
# 833     3699      330       11       56        6  ...        7
# 270     3255      385        6      356        2  ...       13
# 142     1197      368        1       43        0  ...       11
#
#                     tract             county      state    pct_rent  \
# 255     Census Tract 9801    Edmonson County   Kentucky  100.000000
# 508       Census Tract 30   Jefferson County   Kentucky   99.768697
# 200  Census Tract 2015.01   Christian County   Kentucky   99.698568
# 415     Census Tract 2.02      Hardin County   Kentucky   99.679230
# 872     Census Tract 9702       Meade County   Kentucky   99.270960
# 201  Census Tract 2015.02   Christian County   Kentucky   98.896435
# 414     Census Tract 2.01      Hardin County   Kentucky   98.620690
# 833      Census Tract 105     Madison County   Kentucky   96.078431
# 270     Census Tract 8.01     Fayette County   Kentucky   95.617530
# 142      Census Tract 501    Campbell County   Kentucky   94.527363
#
#      pct_black  pct_asian   pct_white   pct_hisp  pct_vacant
# 255   0.000000   0.000000  100.000000   0.000000    0.000000
# 508  89.396914   0.028050    7.237027   1.290323    7.883523
# 200  18.476011   0.884290   67.356538  14.995296    7.072829
# 415  19.118299   1.727957   67.634027  14.842712    5.957768
# 872  15.430488   1.118151   71.412598  15.803205   32.980456
# 201  16.346366   1.347471   67.483985  18.003093    6.507937
# 414  10.858765   1.348474   81.618169  10.432931   28.571429
# 833   7.890961   1.339072   88.450502   1.673840    8.602151
# 270   9.404006   8.695652   79.506595   2.002931   36.775819
# 142  21.234853   2.481246   69.070975   3.693018    7.903780
#
# [10 rows x 40 columns]

# %% [markdown]
# Below we apply this with groupby and use the defaults for n and column, and it applies the function within each county and concatenates the results, producing the top 5 blocks on pop_sqmi for each county in the region.

# %%
sf1.groupby('county').apply(top)
# Out:
#                                      GEO.id      GEO.id2  \
# county
#  Adair County    3     1400000US21001970401  21001970401
#                  4     1400000US21001970402  21001970402
#                  2     1400000US21001970300  21001970300
#                  1     1400000US21001970200  21001970200
#                  5     1400000US21001970500  21001970500
# ...                                     ...          ...
#  Woodford County 1107  1400000US21239050103  21239050103
#                  1113  1400000US21239050300  21239050300
#                  1108  1400000US21239050104  21239050104
#                  1114  1400000US21239050400  21239050400
#                  1109  1400000US21239050105  21239050105
#
#                                                     GEO.display-label  \
# county
#  Adair County    3       Census Tract 9704.01, Adair County, Kentucky
#                  4       Census Tract 9704.02, Adair County, Kentucky
#                  2          Census Tract 9703, Adair County, Kentucky
#                  1          Census Tract 9702, Adair County, Kentucky
#                  5          Census Tract 9705, Adair County, Kentucky
# ...                                                               ...
#  Woodford County 1107  Census Tract 501.03, Woodford County, Kentucky
#                  1113     Census Tract 503, Woodford County, Kentucky
#                  1108  Census Tract 501.04, Woodford County, Kentucky
#                  1114     Census Tract 504, Woodford County, Kentucky
#                  1109  Census Tract 501.05, Woodford County, Kentucky
#
#                        P1-D001  P3-D001  P3-D002  P3-D003  P3-D004  P3-D005  \
# county
#  Adair County    3        4070     4070     3716      237        1       16
#                  4        4261     4261     3950      180       16       16
#                  2        3016     3016     2944        6       11        8
#                  1        1722     1722     1635       41        5        0
#                  5        2457     2457     2402       16        2        5
# ...                        ...      ...      ...      ...      ...      ...
#  Woodford County 1107     3144     3144     2412      406       10        8
#                  1113     1899     1899     1751       23        3       12
#                  1108     3927     3927     3494      237        5       15
#                  1114     2279     2279     2051      122        1        6
#                  1109     3139     3139     2857      138        7       18
#
#                        P3-D006  ...  H5-D008                 tract  \
# county                          ...
#  Adair County    3           1  ...      109  Census Tract 9704.01
#                  4           3  ...       70  Census Tract 9704.02
#                  2           0  ...      106     Census Tract 9703
#                  1           0  ...       35     Census Tract 9702
#                  5           0  ...      104     Census Tract 9705
# ...                        ...  ...      ...                   ...
#  Woodford County 1107        0  ...       32   Census Tract 501.03
#                  1113        6  ...       57      Census Tract 503
#                  1108        2  ...       26   Census Tract 501.04
#                  1114        2  ...       54      Census Tract 504
#                  1109        0  ...       11   Census Tract 501.05
#
#                                  county      state   pct_rent  pct_black  \
# county
#  Adair County    3         Adair County   Kentucky  37.215909   5.823096
#                  4         Adair County   Kentucky  30.911681   4.224360
#                  2         Adair County   Kentucky  20.521173   0.198939
#                  1         Adair County   Kentucky  19.252874   2.380952
#                  5         Adair County   Kentucky  17.972832   0.651201
# ...                                 ...        ...        ...        ...
#  Woodford County 1107   Woodford County   Kentucky  57.563369  12.913486
#                  1113   Woodford County   Kentucky  34.898477   1.211164
#                  1108   Woodford County   Kentucky  32.140691   6.035141
#                  1114   Woodford County   Kentucky  31.228861   5.353225
#                  1109   Woodford County   Kentucky  26.441516   4.396305
#
#                        pct_asian  pct_white   pct_hisp  pct_vacant
# county
#  Adair County    3      0.393120  91.302211   1.547912   10.795743
#                  4      0.375499  92.701244   1.900962   11.642542
#                  2      0.265252  97.612732   1.856764   15.193370
#                  1      0.000000  94.947735   2.613240   25.161290
#                  5      0.203500  97.761498   0.773301   17.641997
# ...                          ...        ...        ...         ...
#  Woodford County 1107   0.254453  76.717557  13.104326    8.320840
#                  1113   0.631912  92.206424   6.424434   14.902808
#                  1108   0.381971  88.973771   5.602241    5.932687
#                  1114   0.263273  89.995612   5.835893   12.091179
#                  1109   0.573431  91.016247   6.690029    6.327160
#
# [504 rows x 40 columns]

# %% [markdown]
# Here we pass arguments to the function to set n and the column to select the top value from.

# %%
sf1.groupby('county').apply(top, n=1, column='P1-D001')
# Out:
#                                      GEO.id      GEO.id2  \
# county
#  Adair County    4     1400000US21001970402  21001970402
#  Allen County    9     1400000US21003920300  21003920300
#  Anderson County 13    1400000US21005950100  21005950100
#  Ballard County  18    1400000US21007950100  21007950100
#  Barren County   26    1400000US21009950600  21009950600
# ...                                     ...          ...
#  Wayne County    1089  1400000US21231920200  21231920200
#  Webster County  1093  1400000US21233960100  21233960100
#  Whitley County  1099  1400000US21235920300  21235920300
#  Wolfe County    1106  1400000US21237930200  21237930200
#  Woodford County 1108  1400000US21239050104  21239050104
#
#                                                     GEO.display-label  \
# county
#  Adair County    4       Census Tract 9704.02, Adair County, Kentucky
#  Allen County    9          Census Tract 9203, Allen County, Kentucky
#  Anderson County 13      Census Tract 9501, Anderson County, Kentucky
#  Ballard County  18       Census Tract 9501, Ballard County, Kentucky
#  Barren County   26        Census Tract 9506, Barren County, Kentucky
# ...                                                               ...
#  Wayne County    1089       Census Tract 9202, Wayne County, Kentucky
#  Webster County  1093     Census Tract 9601, Webster County, Kentucky
#  Whitley County  1099     Census Tract 9203, Whitley County, Kentucky
#  Wolfe County    1106       Census Tract 9302, Wolfe County, Kentucky
#  Woodford County 1108  Census Tract 501.04, Woodford County, Kentucky
#
#                        P1-D001  P3-D001  P3-D002  P3-D003  P3-D004  P3-D005  \
# county
#  Adair County    4        4261     4261     3950      180       16       16
#  Allen County    9        4685     4685     4473       83       19       12
#  Anderson County 13       8164     8164     7647      292        5       38
#  Ballard County  18       4259     4259     4024      145        8       11
#  Barren County   26       5937     5937     5331      299       11       40
# ...                        ...      ...      ...      ...      ...      ...
#  Wayne County    1089     6121     6121     5709      150       24       20
#  Webster County  1093     4584     4584     4203       22        5       18
#  Whitley County  1099     6189     6189     6078        8       28       17
#  Wolfe County    1106     4082     4082     4032        7        7        2
#  Woodford County 1108     3927     3927     3494      237        5       15
#
#                        P3-D006  ...  H5-D008                 tract  \
# county                          ...
#  Adair County    4           3  ...       70  Census Tract 9704.02
#  Allen County    9           0  ...       86     Census Tract 9203
#  Anderson County 13          3  ...      103     Census Tract 9501
#  Ballard County  18          0  ...      132     Census Tract 9501
#  Barren County   26         10  ...       95     Census Tract 9506
# ...                        ...  ...      ...                   ...
#  Wayne County    1089        2  ...       85     Census Tract 9202
#  Webster County  1093       33  ...      101     Census Tract 9601
#  Whitley County  1099        2  ...      108     Census Tract 9203
#  Wolfe County    1106        0  ...      147     Census Tract 9302
#  Woodford County 1108        2  ...       26   Census Tract 501.04
#
#                                  county      state   pct_rent  pct_black  \
# county
#  Adair County    4         Adair County   Kentucky  30.911681   4.224360
#  Allen County    9         Allen County   Kentucky  34.676186   1.771612
#  Anderson County 13     Anderson County   Kentucky  26.186684   3.576678
#  Ballard County  18      Ballard County   Kentucky  22.140011   3.404555
#  Barren County   26       Barren County   Kentucky  44.142343   5.036214
# ...                                 ...        ...        ...        ...
#  Wayne County    1089      Wayne County   Kentucky  37.323391   2.450580
#  Webster County  1093    Webster County   Kentucky  22.176227   0.479930
#  Whitley County  1099    Whitley County   Kentucky  23.053892   0.129262
#  Wolfe County    1106      Wolfe County   Kentucky  33.196961   0.171485
#  Woodford County 1108   Woodford County   Kentucky  32.140691   6.035141
#
#                        pct_asian  pct_white  pct_hisp  pct_vacant
# county
#  Adair County    4      0.375499  92.701244  1.900962   11.642542
#  Allen County    9      0.256137  95.474920  1.173959    9.254975
#  Anderson County 13     0.465458  93.667320  1.641352    8.081991
#  Ballard County  18     0.258277  94.482273  0.986147   11.664153
#  Barren County   26     0.673741  89.792825  2.779181   11.500354
# ...                          ...        ...       ...         ...
#  Wayne County    1089   0.326744  93.269074  4.296684    9.452736
#  Webster County  1093   0.392670  91.688482  9.642234    9.475375
#  Whitley County  1099   0.274681  98.206495  0.727096    9.590101
#  Wolfe County    1106   0.048996  98.775110  0.636943   16.577279
#  Woodford County 1108   0.381971  88.973771  5.602241    5.932687
#
# [120 rows x 40 columns]

# %% [markdown]
# ## Exploring Correlations in the Data
#
# Pandas provides simple ways of computing correlation coefficients among the columns in your DataFrame.  If you use corr() on a full DF, it will produce a large correlation table.  A bit hard to navigate and you mostly would not be interested in some of these results.

# %%
sf1.corr()
# Out:
#              GEO.id2   P1-D001   P3-D001   P3-D002   P3-D003   P3-D004  \
# GEO.id2     1.000000  0.049408  0.049408  0.063873 -0.024147  0.001960
# P1-D001     0.049408  1.000000  1.000000  0.929708  0.150379  0.479878
# P3-D001     0.049408  1.000000  1.000000  0.929708  0.150379  0.479878
# P3-D002     0.063873  0.929708  0.929708  1.000000 -0.213918  0.363714
# P3-D003    -0.024147  0.150379  0.150379 -0.213918  1.000000  0.252784
# P3-D004     0.001960  0.479878  0.479878  0.363714  0.252784  1.000000
# P3-D005    -0.048639  0.324468  0.324468  0.209791  0.158195  0.131467
# P3-D006    -0.031018  0.192667  0.192667  0.095243  0.171271  0.463373
# P3-D007    -0.020234  0.240640  0.240640  0.057796  0.325919  0.299747
# P3-D008    -0.045010  0.581058  0.581058  0.351332  0.497941  0.565977
# P4-D001     0.049408  1.000000  1.000000  0.929708  0.150379  0.479878
# P4-D002     0.051958  0.995049  0.995049  0.944060  0.115575  0.450025
# P4-D003    -0.009904  0.335691  0.335691  0.132437  0.373278  0.421506
# H1-D001     0.050587  0.928844  0.928844  0.860231  0.152325  0.405974
# H3-D001     0.050587  0.928844  0.928844  0.860231  0.152325  0.405974
# H3-D002     0.036080  0.951584  0.951584  0.881048  0.149371  0.404544
# H3-D003     0.088473  0.271559  0.271559  0.252634  0.075813  0.171896
# H4-D001     0.036080  0.951584  0.951584  0.881048  0.149371  0.404544
# H4-D002     0.007697  0.843009  0.843009  0.839511 -0.018171  0.280975
# H4-D003     0.138637  0.564509  0.564509  0.676709 -0.249705  0.112683
# H4-D004    -0.026033  0.491888  0.491888  0.294222  0.454881  0.374664
# H5-D001     0.088473  0.271559  0.271559  0.252634  0.075813  0.171896
# H5-D002    -0.045724  0.325012  0.325012  0.121212  0.495051  0.321275
# H5-D003    -0.018766  0.280196  0.280196  0.221259  0.145035  0.146586
# H5-D004     0.027541  0.560296  0.560296  0.516400  0.096140  0.259889
# H5-D005     0.077670  0.308361  0.308361  0.376236 -0.145718  0.057503
# H5-D006     0.076772  0.012925  0.012925  0.064984 -0.120118  0.000613
# H5-D007     0.010594 -0.023479 -0.023479  0.014118 -0.089171 -0.035805
# H5-D008     0.119563  0.202435  0.202435  0.236156 -0.003757  0.090925
# pct_rent   -0.061820 -0.062520 -0.062520 -0.257852  0.464467  0.184507
# pct_black  -0.033330 -0.070055 -0.070055 -0.391277  0.899663  0.114453
# pct_asian  -0.058690  0.136213  0.136213  0.031737  0.132016  0.060946
# pct_white   0.045403  0.043546  0.043546  0.382284 -0.899986 -0.170683
# pct_hisp   -0.022668  0.058258  0.058258 -0.115163  0.302933  0.299351
# pct_vacant  0.043711 -0.300937 -0.300937 -0.289514  0.011119 -0.015777
#
#              P3-D005   P3-D006   P3-D007   P3-D008  ...   H5-D005   H5-D006  \
# GEO.id2    -0.048639 -0.031018 -0.020234 -0.045010  ...  0.077670  0.076772
# P1-D001     0.324468  0.192667  0.240640  0.581058  ...  0.308361  0.012925
# P3-D001     0.324468  0.192667  0.240640  0.581058  ...  0.308361  0.012925
# P3-D002     0.209791  0.095243  0.057796  0.351332  ...  0.376236  0.064984
# P3-D003     0.158195  0.171271  0.325919  0.497941  ... -0.145718 -0.120118
# P3-D004     0.131467  0.463373  0.299747  0.565977  ...  0.057503  0.000613
# P3-D005     1.000000  0.176404  0.160199  0.399051  ... -0.082495 -0.075145
# P3-D006     0.176404  1.000000  0.281407  0.523912  ... -0.069520 -0.049845
# P3-D007     0.160199  0.281407  1.000000  0.504998  ... -0.108742 -0.086525
# P3-D008     0.399051  0.523912  0.504998  1.000000  ... -0.029011 -0.118407
# P4-D001     0.324468  0.192667  0.240640  0.581058  ...  0.308361  0.012925
# P4-D002     0.306605  0.155325  0.147510  0.530673  ...  0.329091  0.023668
# P4-D003     0.262987  0.409559  0.952141  0.645319  ... -0.107435 -0.098088
# H1-D001     0.287481  0.121031  0.226984  0.543439  ...  0.356114  0.190344
# H3-D001     0.287481  0.121031  0.226984  0.543439  ...  0.356114  0.190344
# H3-D002     0.327364  0.133170  0.238148  0.571502  ...  0.318061  0.028273
# H3-D003    -0.069661 -0.007556  0.040118  0.089816  ...  0.322993  0.835915
# H4-D001     0.327364  0.133170  0.238148  0.571502  ...  0.318061  0.028273
# H4-D002     0.315837  0.051226  0.085445  0.394217  ...  0.214254  0.016528
# H4-D003    -0.099214 -0.114828 -0.117035 -0.080354  ...  0.509714  0.211896
# H4-D004     0.320430  0.263249  0.423441  0.679579  ...  0.043252 -0.095701
# H5-D001    -0.069661 -0.007556  0.040118  0.089816  ...  0.322993  0.835915
# H5-D002     0.198753  0.179376  0.415635  0.527952  ...  0.045884 -0.053027
# H5-D003     0.115346  0.052702  0.104096  0.240108  ...  0.229818  0.012936
# H5-D004     0.188003  0.072948  0.113935  0.379294  ...  0.238450  0.140951
# H5-D005    -0.082495 -0.069520 -0.108742 -0.029011  ...  1.000000  0.124633
# H5-D006    -0.075145 -0.049845 -0.086525 -0.118407  ...  0.124633  1.000000
# H5-D007    -0.105767 -0.029479 -0.017210 -0.088460  ...  0.122742  0.131348
# H5-D008    -0.302912 -0.106864 -0.124005 -0.130512  ...  0.401844  0.247242
# pct_rent    0.163496  0.255751  0.305578  0.425299  ... -0.190747 -0.154840
# pct_black   0.054982  0.099153  0.192686  0.307009  ... -0.205686 -0.122740
# pct_asian   0.923845  0.155861  0.134676  0.306124  ... -0.173270 -0.097524
# pct_white  -0.172315 -0.174929 -0.334419 -0.413328  ...  0.244865  0.144994
# pct_hisp    0.178430  0.339602  0.843366  0.466302  ... -0.206228 -0.113123
# pct_vacant -0.222993 -0.039314 -0.086896 -0.216524  ...  0.102911  0.605394
#
#              H5-D007   H5-D008  pct_rent  pct_black  pct_asian  pct_white  \
# GEO.id2     0.010594  0.119563 -0.061820  -0.033330  -0.058690   0.045403
# P1-D001    -0.023479  0.202435 -0.062520  -0.070055   0.136213   0.043546
# P3-D001    -0.023479  0.202435 -0.062520  -0.070055   0.136213   0.043546
# P3-D002     0.014118  0.236156 -0.257852  -0.391277   0.031737   0.382284
# P3-D003    -0.089171 -0.003757  0.464467   0.899663   0.132016  -0.899986
# P3-D004    -0.035805  0.090925  0.184507   0.114453   0.060946  -0.170683
# P3-D005    -0.105767 -0.302912  0.163496   0.054982   0.923845  -0.172315
# P3-D006    -0.029479 -0.106864  0.255751   0.099153   0.155861  -0.174929
# P3-D007    -0.017210 -0.124005  0.305578   0.192686   0.134676  -0.334419
# P3-D008    -0.088460 -0.130512  0.425299   0.307009   0.306124  -0.413328
# P4-D001    -0.023479  0.202435 -0.062520  -0.070055   0.136213   0.043546
# P4-D002    -0.020753  0.224780 -0.100844  -0.094517   0.116591   0.083076
# P4-D003    -0.032614 -0.153327  0.341945   0.209326   0.222822  -0.358148
# H1-D001    -0.001518  0.307742  0.009458  -0.051772   0.113810   0.030474
# H3-D001    -0.001518  0.307742  0.009458  -0.051772   0.113810   0.030474
# H3-D002    -0.029200  0.208228  0.000833  -0.062419   0.153659   0.033903
# H3-D003     0.128930  0.590933  0.043725   0.028720  -0.139449  -0.003738
# H4-D001    -0.029200  0.208228  0.000833  -0.062419   0.153659   0.033903
# H4-D002    -0.008291 -0.015867 -0.394421  -0.188452   0.138266   0.175858
# H4-D003     0.094051  0.614549 -0.438232  -0.357592  -0.234629   0.414211
# H4-D004    -0.103370  0.031799  0.713602   0.314776   0.274912  -0.388509
# H5-D001     0.128930  0.590933  0.043725   0.028720  -0.139449  -0.003738
# H5-D002    -0.082684  0.141169  0.643804   0.409411   0.174409  -0.463500
# H5-D003    -0.004746  0.201637  0.251193   0.086779   0.067838  -0.097099
# H5-D004    -0.003160  0.080818 -0.080606  -0.016902   0.074860   0.001687
# H5-D005     0.122742  0.401844 -0.190747  -0.205686  -0.173270   0.244865
# H5-D006     0.131348  0.247242 -0.154840  -0.122740  -0.097524   0.144994
# H5-D007     1.000000  0.125675 -0.128460  -0.097392  -0.119400   0.107804
# H5-D008     0.125675  1.000000 -0.099409  -0.000235  -0.380509   0.079789
# pct_rent   -0.128460 -0.099409  1.000000   0.505329   0.252988  -0.575377
# pct_black  -0.097392 -0.000235  0.505329   1.000000   0.078223  -0.977760
# pct_asian  -0.119400 -0.380509  0.252988   0.078223   1.000000  -0.207707
# pct_white   0.107804  0.079789 -0.575377  -0.977760  -0.207707   1.000000
# pct_hisp   -0.014747 -0.224589  0.402619   0.236368   0.215188  -0.402136
# pct_vacant  0.126817  0.418651  0.085586   0.097909  -0.215284  -0.061246
#
#             pct_hisp  pct_vacant
# GEO.id2    -0.022668    0.043711
# P1-D001     0.058258   -0.300937
# P3-D001     0.058258   -0.300937
# P3-D002    -0.115163   -0.289514
# P3-D003     0.302933    0.011119
# P3-D004     0.299351   -0.015777
# P3-D005     0.178430   -0.222993
# P3-D006     0.339602   -0.039314
# P3-D007     0.843366   -0.086896
# P3-D008     0.466302   -0.216524
# P4-D001     0.058258   -0.300937
# P4-D002    -0.032683   -0.296928
# P4-D003     0.869147   -0.123460
# H1-D001     0.036352   -0.166965
# H3-D001     0.036352   -0.166965
# H3-D002     0.051014   -0.316698
# H3-D003    -0.053514    0.628156
# H4-D001     0.051014   -0.316698
# H4-D002    -0.070449   -0.400436
# H4-D003    -0.287054   -0.017196
# H4-D004     0.350390   -0.129741
# H5-D001    -0.053514    0.628156
# H5-D002     0.348180    0.113335
# H5-D003     0.036983    0.036161
# H5-D004     0.010638   -0.044470
# H5-D005    -0.206228    0.102911
# H5-D006    -0.113123    0.605394
# H5-D007    -0.014747    0.126817
# H5-D008    -0.224589    0.418651
# pct_rent    0.402619    0.085586
# pct_black   0.236368    0.097909
# pct_asian   0.215188   -0.215284
# pct_white  -0.402136   -0.061246
# pct_hisp    1.000000   -0.072834
# pct_vacant -0.072834    1.000000
#
# [35 rows x 35 columns]

# %% [markdown]
# It is easy to compute correlation coeffients for a subset of columns.

# %%
sf1[['pct_rent', 'pct_vacant']].corr()
# Out:
#             pct_rent  pct_vacant
# pct_rent    1.000000    0.085586
# pct_vacant  0.085586    1.000000

# %% [markdown]
# And this method can be combined with groupby to compute correlation tables by group.

# %%
sf1.groupby('county')[['pct_rent', 'pct_vacant']].corr()
# Out:
#                              pct_rent  pct_vacant
# county
#  Adair County    pct_rent    1.000000   -0.613912
#                  pct_vacant -0.613912    1.000000
#  Allen County    pct_rent    1.000000   -0.620421
#                  pct_vacant -0.620421    1.000000
#  Anderson County pct_rent    1.000000   -0.534183
# ...                               ...         ...
#  Whitley County  pct_vacant  0.483214    1.000000
#  Wolfe County    pct_rent    1.000000    1.000000
#                  pct_vacant  1.000000    1.000000
#  Woodford County pct_rent    1.000000    0.154547
#                  pct_vacant  0.154547    1.000000
#
# [240 rows x 2 columns]

# %% [markdown]
# ## Your turn to practice:
#
# Count the number of census blocks per county.
#
# Calculate total households per county.
#
# Calculate percent renters by county. (Careful not to calculate the mean percent rental across blocks in a county)
#
# Calculate percent vacant by county.
#
# Calculate mean, min and max vacancy rate (at the block level) by county.
#
# Calculate the 90th percentile of vacancy rate (at the block level) by county.

# %%
#Count the number of census blocks per county
census_blocks_per_county_count = sf1["GEO.id"].groupby(sf1['county']).count().to_frame(name='census_blocks_per_county_count')
census_blocks_per_county_count
# Out:
#                   census_blocks_per_county_count
# county
#  Adair County                                  7
#  Allen County                                  6
#  Anderson County                               5
#  Ballard County                                3
#  Barren County                                10
# ...                                          ...
#  Wayne County                                  5
#  Webster County                                4
#  Whitley County                                8
#  Wolfe County                                  2
#  Woodford County                               8
#
# [120 rows x 1 columns]

# %%
#Calculate total households per county. Households = housing_units?
total_households_per_county = sf1["H1-D001"].groupby(sf1['county']).sum().to_frame(name='total_households_per_county')
total_households_per_county
# Out:
#                   total_households_per_county
# county
#  Adair County                            8568
#  Allen County                            9307
#  Anderson County                         9127
#  Ballard County                          3885
#  Barren County                          19188
# ...                                       ...
#  Wayne County                           10942
#  Webster County                          5936
#  Whitley County                         15166
#  Wolfe County                            3660
#  Woodford County                        10711
#
# [120 rows x 1 columns]

# %%
#Calculate percent renters by county.

renter_df = sf1[['H3-D001', 'H4-D004']].groupby(sf1['county']).sum()
renter_df['percent_renters_by_county'] = renter_df['H4-D004'] / renter_df['H3-D001'] * 100
renter_df
#sf1['pct_rent'] = sf1['H4-D004'] / sf1['H4-D001'] * 100
# percent_renters_by_county = sf1["H1-D001"].groupby(sf1['county']).sum().to_frame(name='percent_renters_by_county')
# percent_renters_by_county
# Out:
#                   H3-D001  H4-D004  percent_renters_by_county
# county
#  Adair County        8568     1860                  21.708683
#  Allen County        9307     1898                  20.393252
#  Anderson County     9127     2067                  22.647091
#  Ballard County      3885      727                  18.712999
#  Barren County      19188     5449                  28.397957
# ...                   ...      ...                        ...
#  Wayne County       10942     2386                  21.805886
#  Webster County      5936     1245                  20.973720
#  Whitley County     15166     4121                  27.172623
#  Wolfe County        3660      876                  23.934426
#  Woodford County    10711     2842                  26.533470
#
# [120 rows x 3 columns]

# %%
#Calculate percent vacant by county.



vacant_df = sf1[['H3-D001', 'H3-D003']].groupby(sf1['county']).sum()
vacant_df['percent_vacant_by_county'] = vacant_df['H3-D003'] / vacant_df['H3-D001'] * 100
vacant_df

#sf1['pct_rent'] = sf1['H4-D004'] / sf1['H4-D001'] * 100
# percent_vacant_by_county =
# percent_vacant_by_county
# Out:
#                   H3-D001  H3-D003  percent_vacant_by_county
# county
#  Adair County        8568     1283                 14.974323
#  Allen County        9307     1459                 15.676373
#  Anderson County     9127      758                  8.305029
#  Ballard County      3885      488                 12.561133
#  Barren County      19188     2189                 11.408172
# ...                   ...      ...                       ...
#  Wayne County       10942     2296                 20.983367
#  Webster County      5936      664                 11.185984
#  Whitley County     15166     1591                 10.490571
#  Wolfe County        3660      595                 16.256831
#  Woodford County    10711      905                  8.449258
#
# [120 rows x 3 columns]

# %%
#Calculate mean, min and max vacancy rate (at the block level) by county.
# vacancy_rate_stats_mean_min_max_by_county =
# vacancy_rate_stats_mean_min_max by_county

mean_vacant_df = sf1[['pct_vacant']].groupby(sf1['county']).mean()
min_vacant_df = sf1[['pct_vacant']].groupby(sf1['county']).min()
max_vacant_df = sf1[['pct_vacant']].groupby(sf1['county']).max()
 
vacancy_rate_stats_mean_min_max_by_county = pd.merge(min_vacant_df, mean_vacant_df, left_on='county', left_index=True, right_index=True)
vacancy_rate_stats_mean_min_max_by_county = pd.merge(vacancy_rate_stats_mean_min_max_by_county, max_vacant_df, left_on='county', left_index=True, right_index=True)
vacancy_rate_stats_mean_min_max_by_county
vacancy_rate_stats_mean_min_max_by_county.columns = ['min', 'mean', 'max']
vacancy_rate_stats_mean_min_max_by_county

# new_df = sf1[['H4-D001', 'H4-D003', "H4-D004"]].groupby(sf1['county']).sum()
# new_df
# new_df['percent_vacant_by_county'] = vacant_df['H4-D003'] / vacant_df['H4-D001'] * 100
# vacant_df
# Out:
#                         min       mean        max
# county
#  Adair County     10.795743  15.868316  25.161290
#  Allen County      9.254975  15.808521  27.559055
#  Anderson County   5.492297   8.927276  13.452028
#  Ballard County   11.608392  12.640382  14.648603
#  Barren County     7.457767  11.444842  22.975207
# ...                     ...        ...        ...
#  Wayne County      9.452736  18.476934  41.228851
#  Webster County    9.475375  11.019754  13.524590
#  Whitley County    8.378044  10.906092  13.972810
#  Wolfe County     15.848353  16.212816  16.577279
#  Woodford County   5.932687   8.901439  14.902808
#
# [120 rows x 3 columns]

# %%
#Calculate the 90th percentile of vacancy rate (at the block level) by county.
vacancy_rate_stats_ninety_percentile_by_county = sf1[['pct_vacant']].groupby(sf1['county']).quantile(.9)
vacancy_rate_stats_ninety_percentile_by_county.columns = ['90th_percentile']
vacancy_rate_stats_ninety_percentile_by_county
# Out:
#                   90th_percentile
# county
#  Adair County           20.649714
#  Allen County           22.324254
#  Anderson County        12.075984
#  Ballard County         14.051713
#  Barren County          15.985510
# ...                           ...
#  Wayne County           31.434558
#  Webster County         12.664168
#  Whitley County         12.706375
#  Wolfe County           16.504387
#  Woodford County        12.934668
#
# [120 rows x 1 columns]

# %% [markdown]
# ## Some review:
#
# I've included in the data folder a shapefile with the Census geographies.  Can you use it to:
#
# 1. Calculate the population density of each Census tract and county in Kentucky.
# 2. Make a choropleth showing the population density.

# %%
import geopandas
path = './data/{}'.format
census_geo = geopandas.GeoDataFrame.from_file(path('gz_2010_21_140_00_500k.shp'))
census_geo
# Out:
#                     GEO_ID STATE COUNTY   TRACT    NAME   LSAD  CENSUSAREA  \
# 0     1400000US21035010700    21    035  010700     107  Tract      74.333
# 1     1400000US21037050100    21    037  050100     501  Tract       0.205
# 2     1400000US21037050400    21    037  050400     504  Tract       0.186
# 3     1400000US21037052100    21    037  052100     521  Tract       0.433
# 4     1400000US21037052200    21    037  052200     522  Tract       0.452
# ...                    ...   ...    ...     ...     ...    ...         ...
# 1110  1400000US21239050105    21    239  050105  501.05  Tract       1.928
# 1111  1400000US21239050106    21    239  050106  501.06  Tract       5.583
# 1112  1400000US21239050107    21    239  050107  501.07  Tract       4.958
# 1113  1400000US21239050200    21    239  050200     502  Tract      74.749
# 1114  1400000US21239050300    21    239  050300     503  Tract      58.799
#
#                                                geometry
# 0     POLYGON ((-88.43011 36.50090, -88.45016 36.501...
# 1     POLYGON ((-84.50608 39.09508, -84.50206 39.096...
# 2     POLYGON ((-84.48395 39.09684, -84.48151 39.095...
# 3     POLYGON ((-84.49355 39.10272, -84.48774 39.110...
# 4     POLYGON ((-84.46286 39.09985, -84.46695 39.097...
# ...                                                 ...
# 1110  POLYGON ((-84.74664 38.03602, -84.74513 38.037...
# 1111  POLYGON ((-84.72462 38.03148, -84.72424 38.035...
# 1112  POLYGON ((-84.71406 38.05093, -84.70282 38.049...
# 1113  POLYGON ((-84.72344 38.02521, -84.72288 38.022...
# 1114  POLYGON ((-84.73681 38.07039, -84.73801 38.068...
#
# [1115 rows x 8 columns]

# %%
#Inner Merge data frames
census_geo_sf1 = pd.merge(census_geo, sf1, how='inner', left_on='GEO_ID', right_on='GEO.id')
census_geo_sf1.head
# Out:
# <bound method NDFrame.head of                     GEO_ID STATE COUNTY   TRACT    NAME   LSAD  CENSUSAREA  \
# 0     1400000US21035010700    21    035  010700     107  Tract      74.333
# 1     1400000US21037050100    21    037  050100     501  Tract       0.205
# 2     1400000US21037050400    21    037  050400     504  Tract       0.186
# 3     1400000US21037052100    21    037  052100     521  Tract       0.433
# 4     1400000US21037052200    21    037  052200     522  Tract       0.452
# ...                    ...   ...    ...     ...     ...    ...         ...
# 1110  1400000US21239050105    21    239  050105  501.05  Tract       1.928
# 1111  1400000US21239050106    21    239  050106  501.06  Tract       5.583
# 1112  1400000US21239050107    21    239  050107  501.07  Tract       4.958
# 1113  1400000US21239050200    21    239  050200     502  Tract      74.749
# 1114  1400000US21239050300    21    239  050300     503  Tract      58.799
#
#                                                geometry                GEO.id  \
# 0     POLYGON ((-88.43011 36.50090, -88.45016 36.501...  1400000US21035010700
# 1     POLYGON ((-84.50608 39.09508, -84.50206 39.096...  1400000US21037050100
# 2     POLYGON ((-84.48395 39.09684, -84.48151 39.095...  1400000US21037050400
# 3     POLYGON ((-84.49355 39.10272, -84.48774 39.110...  1400000US21037052100
# 4     POLYGON ((-84.46286 39.09985, -84.46695 39.097...  1400000US21037052200
# ...                                                 ...                   ...
# 1110  POLYGON ((-84.74664 38.03602, -84.74513 38.037...  1400000US21239050105
# 1111  POLYGON ((-84.72462 38.03148, -84.72424 38.035...  1400000US21239050106
# 1112  POLYGON ((-84.71406 38.05093, -84.70282 38.049...  1400000US21239050107
# 1113  POLYGON ((-84.72344 38.02521, -84.72288 38.022...  1400000US21239050200
# 1114  POLYGON ((-84.73681 38.07039, -84.73801 38.068...  1400000US21239050300
#
#           GEO.id2  ... H5-D008                tract            county  \
# 0     21035010700  ...      61     Census Tract 107   Calloway County
# 1     21037050100  ...      11     Census Tract 501   Campbell County
# 2     21037050400  ...      45     Census Tract 504   Campbell County
# 3     21037052100  ...      67     Census Tract 521   Campbell County
# 4     21037052200  ...      29     Census Tract 522   Campbell County
# ...           ...  ...     ...                  ...               ...
# 1110  21239050105  ...      11  Census Tract 501.05   Woodford County
# 1111  21239050106  ...      22  Census Tract 501.06   Woodford County
# 1112  21239050107  ...      10  Census Tract 501.07   Woodford County
# 1113  21239050200  ...      61     Census Tract 502   Woodford County
# 1114  21239050300  ...      57     Census Tract 503   Woodford County
#
#           state   pct_rent  pct_black  pct_asian  pct_white  pct_hisp  \
# 0      Kentucky  15.887157   1.098566   0.396704  97.070491  2.075069
# 1      Kentucky  94.527363  21.234853   2.481246  69.070975  3.693018
# 2      Kentucky  40.245399   4.306220   0.850611  90.855928  4.146730
# 3      Kentucky  43.000000   1.568400   0.726111  94.859134  2.555911
# 4      Kentucky  18.307268   0.582848   0.541216  97.543714  1.748543
# ...         ...        ...        ...        ...        ...       ...
# 1110   Kentucky  26.441516   4.396305   0.573431  91.016247  6.690029
# 1111   Kentucky  19.984627   2.790555   0.490647  93.897577  5.826434
# 1112   Kentucky  19.793966   4.897525   0.718659  88.235294  8.357732
# 1113   Kentucky  14.873646   0.820832   0.622700  96.829890  2.236060
# 1114   Kentucky  34.898477   1.211164   0.631912  92.206424  6.424434
#
#       pct_vacant
# 0       9.047941
# 1       7.903780
# 2      16.152263
# 3      12.536443
# 4       9.265442
# ...          ...
# 1110    6.327160
# 1111    7.795889
# 1112    5.951557
# 1113    9.889395
# 1114   14.902808
#
# [1115 rows x 48 columns]>

# %%
#Calculate the population density of each Census tract and county in Kentucky.

census_geo_sf1['block_population_density'] = census_geo_sf1['P1-D001'] / census_geo_sf1['CENSUSAREA']
census_geo_sf1
# Out:
#                     GEO_ID STATE COUNTY   TRACT    NAME   LSAD  CENSUSAREA  \
# 0     1400000US21035010700    21    035  010700     107  Tract      74.333
# 1     1400000US21037050100    21    037  050100     501  Tract       0.205
# 2     1400000US21037050400    21    037  050400     504  Tract       0.186
# 3     1400000US21037052100    21    037  052100     521  Tract       0.433
# 4     1400000US21037052200    21    037  052200     522  Tract       0.452
# ...                    ...   ...    ...     ...     ...    ...         ...
# 1110  1400000US21239050105    21    239  050105  501.05  Tract       1.928
# 1111  1400000US21239050106    21    239  050106  501.06  Tract       5.583
# 1112  1400000US21239050107    21    239  050107  501.07  Tract       4.958
# 1113  1400000US21239050200    21    239  050200     502  Tract      74.749
# 1114  1400000US21239050300    21    239  050300     503  Tract      58.799
#
#                                                geometry                GEO.id  \
# 0     POLYGON ((-88.43011 36.50090, -88.45016 36.501...  1400000US21035010700
# 1     POLYGON ((-84.50608 39.09508, -84.50206 39.096...  1400000US21037050100
# 2     POLYGON ((-84.48395 39.09684, -84.48151 39.095...  1400000US21037050400
# 3     POLYGON ((-84.49355 39.10272, -84.48774 39.110...  1400000US21037052100
# 4     POLYGON ((-84.46286 39.09985, -84.46695 39.097...  1400000US21037052200
# ...                                                 ...                   ...
# 1110  POLYGON ((-84.74664 38.03602, -84.74513 38.037...  1400000US21239050105
# 1111  POLYGON ((-84.72462 38.03148, -84.72424 38.035...  1400000US21239050106
# 1112  POLYGON ((-84.71406 38.05093, -84.70282 38.049...  1400000US21239050107
# 1113  POLYGON ((-84.72344 38.02521, -84.72288 38.022...  1400000US21239050200
# 1114  POLYGON ((-84.73681 38.07039, -84.73801 38.068...  1400000US21239050300
#
#           GEO.id2  ...                tract            county      state  \
# 0     21035010700  ...     Census Tract 107   Calloway County   Kentucky
# 1     21037050100  ...     Census Tract 501   Campbell County   Kentucky
# 2     21037050400  ...     Census Tract 504   Campbell County   Kentucky
# 3     21037052100  ...     Census Tract 521   Campbell County   Kentucky
# 4     21037052200  ...     Census Tract 522   Campbell County   Kentucky
# ...           ...  ...                  ...               ...        ...
# 1110  21239050105  ...  Census Tract 501.05   Woodford County   Kentucky
# 1111  21239050106  ...  Census Tract 501.06   Woodford County   Kentucky
# 1112  21239050107  ...  Census Tract 501.07   Woodford County   Kentucky
# 1113  21239050200  ...     Census Tract 502   Woodford County   Kentucky
# 1114  21239050300  ...     Census Tract 503   Woodford County   Kentucky
#
#        pct_rent  pct_black  pct_asian  pct_white  pct_hisp  pct_vacant  \
# 0     15.887157   1.098566   0.396704  97.070491  2.075069    9.047941
# 1     94.527363  21.234853   2.481246  69.070975  3.693018    7.903780
# 2     40.245399   4.306220   0.850611  90.855928  4.146730   16.152263
# 3     43.000000   1.568400   0.726111  94.859134  2.555911   12.536443
# 4     18.307268   0.582848   0.541216  97.543714  1.748543    9.265442
# ...         ...        ...        ...        ...       ...         ...
# 1110  26.441516   4.396305   0.573431  91.016247  6.690029    6.327160
# 1111  19.984627   2.790555   0.490647  93.897577  5.826434    7.795889
# 1112  19.793966   4.897525   0.718659  88.235294  8.357732    5.951557
# 1113  14.873646   0.820832   0.622700  96.829890  2.236060    9.889395
# 1114  34.898477   1.211164   0.631912  92.206424  6.424434   14.902808
#
#       block_population_density
# 0                    44.085399
# 1                  8453.658537
# 2                 10112.903226
# 3                  7951.501155
# 4                  5314.159292
# ...                        ...
# 1110               1628.112033
# 1111                584.094573
# 1112                757.765228
# 1113                 47.264846
# 1114                 32.296468
#
# [1115 rows x 49 columns]

# %%
tract_pop_density_df = census_geo_sf1[['block_population_density']].groupby(census_geo_sf1['TRACT']).sum()
tract_pop_density_df.columns = ['tract_population_density']
tract_pop_density_df
# Out:
#         tract_population_density
# TRACT
# 000100               3578.309952
# 000101               6107.355865
# 000102               5137.704918
# 000200              10170.930908
# 000201                334.441016
# ...                          ...
# 971101                 27.104522
# 971102                231.414375
# 971300                 88.423475
# 980100                 18.956566
# 980200                  0.169847
#
# [610 rows x 1 columns]

# %%
county_pop_density_df = census_geo_sf1[['block_population_density']].groupby(census_geo_sf1['COUNTY']).sum()
county_pop_density_df.columns = ['county_population_density']
county_pop_density_df
# Out:
#         county_population_density
# COUNTY
# 001                    423.407887
# 003                    426.516891
# 005                   1724.567264
# 007                     97.221207
# 009                   2007.252580
# ...                           ...
# 231                    553.825217
# 233                    177.299384
# 235                   2535.733995
# 237                     68.508779
# 239                   4140.320644
#
# [120 rows x 1 columns]

# %%
#Merge data into larger frame
census_geo_sf1 = pd.merge(census_geo_sf1, tract_pop_density_df, how='inner', left_on='TRACT', right_on='TRACT')
census_geo_sf1 = pd.merge(census_geo_sf1, county_pop_density_df, how='inner', left_on='COUNTY', right_on='COUNTY')


census_geo_sf1.head
# Out:
# <bound method NDFrame.head of                     GEO_ID STATE COUNTY   TRACT    NAME   LSAD  CENSUSAREA  \
# 0     1400000US21035010700    21    035  010700     107  Tract      74.333
# 1     1400000US21035010500    21    035  010500     105  Tract      12.033
# 2     1400000US21035010800    21    035  010800     108  Tract      98.398
# 3     1400000US21035010301    21    035  010301  103.01  Tract       0.504
# 4     1400000US21035010400    21    035  010400     104  Tract      10.723
# ...                    ...   ...    ...     ...     ...    ...         ...
# 1110  1400000US21215080102    21    215  080102  801.02  Tract      35.944
# 1111  1400000US21215080103    21    215  080103  801.03  Tract      41.483
# 1112  1400000US21215080200    21    215  080200     802  Tract      91.060
# 1113  1400000US21223100100    21    223  100100    1001  Tract      48.688
# 1114  1400000US21223100200    21    223  100200    1002  Tract     102.960
#
#                                                geometry                GEO.id  \
# 0     POLYGON ((-88.43011 36.50090, -88.45016 36.501...  1400000US21035010700
# 1     POLYGON ((-88.28780 36.61252, -88.28257 36.613...  1400000US21035010500
# 2     POLYGON ((-88.11513 36.63316, -88.10867 36.635...  1400000US21035010800
# 3     POLYGON ((-88.32433 36.62126, -88.32433 36.622...  1400000US21035010301
# 4     POLYGON ((-88.28780 36.61252, -88.29182 36.611...  1400000US21035010400
# ...                                                 ...                   ...
# 1110  POLYGON ((-85.42768 38.12582, -85.42417 38.146...  1400000US21215080102
# 1111  POLYGON ((-85.34755 38.02775, -85.34668 38.026...  1400000US21215080103
# 1112  POLYGON ((-85.23264 38.08950, -85.19612 38.074...  1400000US21215080200
# 1113  POLYGON ((-85.37000 38.73055, -85.36383 38.730...  1400000US21223100100
# 1114  POLYGON ((-85.43292 38.52406, -85.42579 38.528...  1400000US21223100200
#
#           GEO.id2  ...      state   pct_rent  pct_black  pct_asian  pct_white  \
# 0     21035010700  ...   Kentucky  15.887157   1.098566   0.396704  97.070491
# 1     21035010500  ...   Kentucky  46.319444   6.353768   1.340996  89.303959
# 2     21035010800  ...   Kentucky  16.156915   0.202429   0.173511  97.802198
# 3     21035010301  ...   Kentucky  77.053824   8.885350   8.439490  79.936306
# 4     21035010400  ...   Kentucky  58.222676  11.043478   2.086957  81.782609
# ...           ...  ...        ...        ...        ...        ...        ...
# 1110  21215080102  ...   Kentucky  10.764588   1.480437   0.616849  96.351780
# 1111  21215080103  ...   Kentucky  15.193370   0.704935   0.050352  97.331319
# 1112  21215080200  ...   Kentucky  23.705086   1.850882   0.174611  95.791863
# 1113  21223100100  ...   Kentucky  21.649485   0.088209   0.176419  96.912673
# 1114  21223100200  ...   Kentucky  21.968962   0.443787   0.591716  96.079882
#
#       pct_hisp  pct_vacant  block_population_density  \
# 0     2.075069    9.047941                 44.085399
# 1     2.777778   12.302071                260.284218
# 2     1.272412   28.449096                 35.142991
# 3     2.197452   12.839506               6230.158730
# 4     6.000000   14.423077                214.492213
# ...        ...         ...                       ...
# 1110  1.374692    5.558195                157.856666
# 1111  1.158107    8.701135                 47.875033
# 1112  1.414353   11.955629                 62.892598
# 1113  2.411056   15.599751                 69.852941
# 1114  2.607249   11.158983                 52.525253
#
#       tract_population_density  county_population_density
# 0                    44.085399                8096.422358
# 1                 13204.472220                8096.422358
# 2                  3776.315197                8096.422358
# 3                  6230.158730                8096.422358
# 4                 18572.630195                8096.422358
# ...                        ...                        ...
# 1110                157.856666                 470.592304
# 1111                 47.875033                 470.592304
# 1112                 62.892598                 470.592304
# 1113                 69.852941                 122.378194
# 1114                 52.525253                 122.378194
#
# [1115 rows x 51 columns]>

# %%
import folium
starting_point = [38.034,-84.500]
tract_map = folium.Map(starting_point, zoom_start = 9)
tract_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
tract_pop_density_df
tract_pop_density_df['TRACT'] = tract_pop_density_df.index

tract_bins = list(tract_pop_density_df['tract_population_density'].quantile([0, 0.25, 0.5, 0.75, 1]))
tract_bins
# Out:
# [0.1698465719300232,
#  375.45775702636195,
#  1841.3955160480073,
#  4096.635043877691,
#  20491.79804553398]

# %%
# tract_map.choropleth(geo_str = gdf_wgs84.to_json(), data = census_geo_sf1,
#                 columns = ['TRACT', 'tract_population_density'], key_on = 'feature.properties.{}'.format('TRACT'),
#                 fill_color = fill_color, fill_opacity = fill_opacity, line_opacity = line_opacity,  
#                 threshold_scale = threshold_scale)



starting_point = [38.034,-84.500]
tract_map = folium.Map(starting_point, zoom_start = 9)
tract_map
folium.Choropleth(
    geo_data=census_geo,
    name='choropleth',
    data=tract_pop_density_df,
    columns=['TRACT', 'tract_population_density'],
    key_on='feature.properties.TRACT',
    fill_color='RdPu',
    fill_opacity=0.7,
    line_opacity=0.2,
    legend_name='Tract Population Density'
    #bins=tract_bins
).add_to(tract_map)

folium.LayerControl().add_to(tract_map)
tract_map
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-31-c80d13627b73> in <module>
#      18     fill_opacity=0.7,
#      19     line_opacity=0.2,
# ---> 20     legend_name='Tract Population Density'
#      21     #bins=tract_bins
#      22 ).add_to(tract_map)
#
# C:\ProgramData\Anaconda3\lib\site-packages\folium\features.py in __init__(self, geo_data, data, columns, key_on, bins, fill_color, nan_fill_color, fill_opacity, nan_fill_opacity, line_color, line_weight, line_opacity, name, legend_name, overlay, control, show, topojson, smooth_factor, highlight, **kwargs)
#    1156                 style_function=style_function,
#    1157                 smooth_factor=smooth_factor,
# -> 1158                 highlight_function=highlight_function if highlight else None)
#    1159
#    1160         self.add_child(self.geojson)
#
# C:\ProgramData\Anaconda3\lib\site-packages\folium\features.py in __init__(self, data, style_function, highlight_function, name, overlay, control, show, smooth_factor, tooltip, embed)
#     450         self.highlight = highlight_function is not None
#     451
# --> 452         self.data = self.process_data(data)
#     453
#     454         if self.style or self.highlight:
#
# C:\ProgramData\Anaconda3\lib\site-packages\folium\features.py in process_data(self, data)
#     490             self.embed = True
#     491             if hasattr(data, 'to_crs'):
# --> 492                 data = data.to_crs(epsg='4326')
#     493             return json.loads(json.dumps(data.__geo_interface__))
#     494         else:
#
# C:\ProgramData\Anaconda3\lib\site-packages\geopandas\geodataframe.py in to_crs(self, crs, epsg, inplace)
#     532         else:
#     533             df = self.copy()
# --> 534         geom = df.geometry.to_crs(crs=crs, epsg=epsg)
#     535         df.geometry = geom
#     536         df.crs = geom.crs
#
# C:\ProgramData\Anaconda3\lib\site-packages\geopandas\geoseries.py in to_crs(self, crs, epsg)
#     421             project = transformer.transform
#     422         else:
# --> 423             proj_in = pyproj.Proj(self.crs, preserve_units=True)
#     424             proj_out = pyproj.Proj(crs, preserve_units=True)
#     425             project = partial(pyproj.transform, proj_in, proj_out)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pyproj\__init__.py in __new__(self, projparams, preserve_units, **kwargs)
#     360         # on case-insensitive filesystems).
#     361         projstring = projstring.replace('EPSG','epsg')
# --> 362         return _proj.Proj.__new__(self, projstring)
#     363
#     364     def __call__(self, *args, **kw):
#
# _proj.pyx in _proj.Proj.__cinit__()
#
# RuntimeError: b'no arguments in initialization list'

# %%
county_pop_density_df
county_pop_density_df['COUNTY'] = county_pop_density_df.index

county_bins = list(county_pop_density_df['county_population_density'].quantile([0, 0.25, 0.5, 0.75, 1]))
county_bins
# Out:
# [20.23328958121796,
#  152.15919167375733,
#  391.8998713915802,
#  2541.2334779115276,
#  723850.4241158095]

# %%
starting_point = [38.034,-84.500]
county_map = folium.Map(starting_point, zoom_start = 9)
county_map
folium.Choropleth(
    geo_data=census_geo,
    name='choropleth',
    data=county_pop_density_df,
    columns=['COUNTY', 'county_population_density'],
    key_on='feature.properties.COUNTY',
    fill_color='YlGn',
    fill_opacity=0.7,
    line_opacity=0.2,
    legend_name='County Population Density'
    #bins=county_bins
).add_to(county_map)

folium.LayerControl().add_to(county_map)
county_map
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-33-b925e595436a> in <module>
#      11     fill_opacity=0.7,
#      12     line_opacity=0.2,
# ---> 13     legend_name='County Population Density'
#      14     #bins=county_bins
#      15 ).add_to(county_map)
#
# C:\ProgramData\Anaconda3\lib\site-packages\folium\features.py in __init__(self, geo_data, data, columns, key_on, bins, fill_color, nan_fill_color, fill_opacity, nan_fill_opacity, line_color, line_weight, line_opacity, name, legend_name, overlay, control, show, topojson, smooth_factor, highlight, **kwargs)
#    1156                 style_function=style_function,
#    1157                 smooth_factor=smooth_factor,
# -> 1158                 highlight_function=highlight_function if highlight else None)
#    1159
#    1160         self.add_child(self.geojson)
#
# C:\ProgramData\Anaconda3\lib\site-packages\folium\features.py in __init__(self, data, style_function, highlight_function, name, overlay, control, show, smooth_factor, tooltip, embed)
#     450         self.highlight = highlight_function is not None
#     451
# --> 452         self.data = self.process_data(data)
#     453
#     454         if self.style or self.highlight:
#
# C:\ProgramData\Anaconda3\lib\site-packages\folium\features.py in process_data(self, data)
#     490             self.embed = True
#     491             if hasattr(data, 'to_crs'):
# --> 492                 data = data.to_crs(epsg='4326')
#     493             return json.loads(json.dumps(data.__geo_interface__))
#     494         else:
#
# C:\ProgramData\Anaconda3\lib\site-packages\geopandas\geodataframe.py in to_crs(self, crs, epsg, inplace)
#     532         else:
#     533             df = self.copy()
# --> 534         geom = df.geometry.to_crs(crs=crs, epsg=epsg)
#     535         df.geometry = geom
#     536         df.crs = geom.crs
#
# C:\ProgramData\Anaconda3\lib\site-packages\geopandas\geoseries.py in to_crs(self, crs, epsg)
#     421             project = transformer.transform
#     422         else:
# --> 423             proj_in = pyproj.Proj(self.crs, preserve_units=True)
#     424             proj_out = pyproj.Proj(crs, preserve_units=True)
#     425             project = partial(pyproj.transform, proj_in, proj_out)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pyproj\__init__.py in __new__(self, projparams, preserve_units, **kwargs)
#     360         # on case-insensitive filesystems).
#     361         projstring = projstring.replace('EPSG','epsg')
# --> 362         return _proj.Proj.__new__(self, projstring)
#     363
#     364     def __call__(self, *args, **kw):
#
# _proj.pyx in _proj.Proj.__cinit__()
#
# RuntimeError: b'no arguments in initialization list'

# %%
starting_point = [38.034,-84.500]
joined_map = folium.Map(starting_point, zoom_start = 9)
joined_map
#add county info
folium.Choropleth(
    geo_data=census_geo,
    name='County Data choropleth',
    data=county_pop_density_df,
    columns=['COUNTY', 'county_population_density'],
    key_on='feature.properties.COUNTY',
    fill_color='YlGn',
    fill_opacity=0.7,
    line_opacity=0.2,
    legend_name='County Population Density'
    #bins=county_bins
).add_to(joined_map)
#add tract info
folium.Choropleth(
    geo_data=census_geo,
    name='Tract Data choropleth',
    data=tract_pop_density_df,
    columns=['TRACT', 'tract_population_density'],
    key_on='feature.properties.TRACT',
    fill_color='RdPu',
    fill_opacity=0.7,
    line_opacity=0.2,
    legend_name='Tract Population Density'
    #bins=tract_bins
).add_to(joined_map)

folium.LayerControl().add_to(joined_map)
joined_map
