# %%
import pyproj
import osmnx as ox
ox.plot_graph(ox.graph_from_place('Modena, Italy'))
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-3-3164ae59f536> in <module>
#       1 import pyproj
# ----> 2 import osmnx as ox
#       3 ox.plot_graph(ox.graph_from_place('Modena, Italy'))
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\osmnx\__init__.py in <module>
#       7 ################################################################################
#       8
# ----> 9 from .core import *
#      10 from .downloader import *
#      11 from .elevation import *
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\osmnx\core.py in <module>
#       7 ################################################################################
#       8
# ----> 9 import geopandas as gpd
#      10 import logging as lg
#      11 import math
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\geopandas\__init__.py in <module>
# ...
