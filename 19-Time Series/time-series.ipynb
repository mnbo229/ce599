# %% [markdown]
# # Time-Series Modeling
#
# This lesson is adapted from Sean Abu:
#
# http://www.seanabu.com/2016/03/22/time-series-seasonal-ARIMA-model-in-python/
#
# With examples from Forecasting Principles and Practice, by Hyndman and Athanastopoulos:
#
# https://www.otexts.org/fpp
#
# The latter is an excellent text book and worth checking out.  I also recommend their fpp package for R, which provides some nice functionality to auto-select the order of an ARIMA model.
#
# ### Basics
#
# A time-series is a series of data points indexed in time order.  It is naturally one-dimensional, and for our purposes we will consider that all points are equally spaced.
#
# We may want to model time series for either inference (understanding statistical relationships), or for forecasting.  We may select different approaches depending on our interest.  There are two main approaches we will consider here:
#
# 1. Regression on time-series data. This is about predicting a time series based on exogenous variables.
# 2. ARIMA modeling.  This is about predicting a time series as a function of its past values.
#
# We can also combine the two: ARIMA models with exogenous regressors.
#
# The focus today is on the modeling.  Pandas provides some nice data wrangling methods for working with time series data which are documented here:
#
# http://pandas.pydata.org/pandas-docs/stable/timeseries.html

# %% [markdown]
# ### Regression on time-series data

# %%
# %matplotlib inline

import pandas as pd
import seaborn as sns
import numpy as np
import statsmodels.api as sm
import statsmodels.formula.api as smf

# %%
# This data has
air = pd.read_csv('data/ausair.csv', parse_dates=['YEAR'], index_col='YEAR')
air
# Out:
#                AUSAIR  GUINEARICE
# YEAR
# 1970-01-01   7.318700    0.311405
# 1971-01-01   7.326600    0.325180
# 1972-01-01   7.795600    0.339565
# 1973-01-01   9.384600    0.354580
# 1974-01-01  10.664700    0.370265
# 1975-01-01  11.055100    0.386640
# 1976-01-01  10.864300    0.403740
# 1977-01-01  11.306500    0.421600
# 1978-01-01  12.122300    0.440250
# 1979-01-01  13.022500    0.459720
# 1980-01-01  13.648800    0.480055
# 1981-01-01  13.219500    0.501290
# 1982-01-01  13.187900    0.523460
# 1983-01-01  12.601500    0.546610
# 1984-01-01  13.236800    0.570790
# 1985-01-01  14.412100    0.596035
# 1986-01-01  15.497300    0.622395
# 1987-01-01  16.880200    0.649925
# 1988-01-01  18.816300    0.678670
# 1989-01-01  15.114300    0.708690
# 1990-01-01  17.553400    0.740035
# 1991-01-01  21.860100    0.772765
# 1992-01-01  23.886600    0.806945
# 1993-01-01  26.929300    0.842635
# 1994-01-01  26.888500    0.879905
# 1995-01-01  28.831400    0.918825
# 1996-01-01  30.075100    0.959460
# 1997-01-01  30.953500    1.001900
# 1998-01-01  30.185700    1.046220
# 1999-01-01  31.579700    1.092490
# 2000-01-01  32.577569    1.140810
# 2001-01-01  33.477398    1.033520
# 2002-01-01  39.021581    1.088670
# 2003-01-01  41.386432    1.146760
# 2004-01-01  41.596552    1.207960
# 2005-01-01  44.657324    1.272420
# 2006-01-01  46.951775    1.340310
# 2007-01-01  48.728837    1.401590
# 2008-01-01  51.488427    1.534090
# 2009-01-01  50.026967    1.499000

# %%
# Both time series are growing over the period of interest...

air.plot(subplots=True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x000001C9D72BC588>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000001C9D933F2C8>],
#       dtype=object)

# %%
# when we plot them against each other, they look to be highly correlated...

sns.jointplot(x="GUINEARICE", y="AUSAIR", data=air)

# %%
# so let's estimate a regression model

mod = smf.ols(formula='AUSAIR ~ GUINEARICE', data=air)
res = mod.fit()
print(res.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 AUSAIR   R-squared:                       0.971
# Model:                            OLS   Adj. R-squared:                  0.970
# Method:                 Least Squares   F-statistic:                     1272.
# Date:                Tue, 07 Apr 2020   Prob (F-statistic):           7.94e-31
# Time:                        12:40:11   Log-Likelihood:                -89.643
# No. Observations:                  40   AIC:                             183.3
# Df Residuals:                      38   BIC:                             186.7
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -5.7297      0.903     -6.348      0.000      -7.557      -3.902
# GUINEARICE    37.4101      1.049     35.672      0.000      35.287      39.533
# ==============================================================================
# Omnibus:                        1.905   Durbin-Watson:                   0.491
# Prob(Omnibus):                  0.386   Jarque-Bera (JB):                1.655
# Skew:                          -0.485   Prob(JB):                        0.437
# Kurtosis:                       2.774   Cond. No.                         4.73
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# #### Woohoo!  We got an r-squared of 0.97.  This is a great model!  Right?

# %% [markdown]
# Sorry to disappoint, but this is an example of **spurious regression**.  Spurious regression can happen when working with time series that are non-stationary.
#
# I would add that the model lacks a theoretical basis as well.  It clearly falls in the category of "If you can't explain it, you can't use it!"  However, spurious regression can occur even when there is a theoretical basis for the model.
#
# A stationary time series is one whose properties do not depend on the time at which the series is observed.  To avoid spurious regression, we want the dependent variable and all regressors to be stationary.

# %% [markdown]
# One way to tell if data are stationary is to plot them, and look for either a trend or a cycle

# %%
# check for trend or cycle

air.plot(subplots=True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x000001C9D96238C8>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000001C9D97D6888>],
#       dtype=object)

# %% [markdown]
# We can also look at plots of the auto-correlation function (ACF).  auto-correlation is the correlation of the time-series past values.  There are some statistical tests for this as well, but often a graphical analysis is good enough.

# %%
# ACF plots
#correlation with previous data points - this shows high correlation as a function of time (corrleated with itself)
#also visibile in the trend in the two grapsh below
fig = sm.graphics.tsa.plot_acf(air['AUSAIR'], lags=30)
fig = sm.graphics.tsa.plot_acf(air['GUINEARICE'], lags=30)

# %% [markdown]
# What do we do if the data are not stationary?  There are a few strategies, but differencing usually works.  All this means is subtracting each value from the previous value.  That way, you are modeling the change, rather than the total value.

# %%
#solution: do somethng called differencing
#modleing teh change between the previous values isntead of the values themselves
# shift moves things by the specified number of rows --> shift(1) means 1 period back

air['AUSAIR_DIFF'] = air['AUSAIR'] - air['AUSAIR'].shift(1)  
air['GUINEARICE_DIFF'] = air['GUINEARICE'] - air['GUINEARICE'].shift(1)  
air.head()
# Out:
#              AUSAIR  GUINEARICE  AUSAIR_DIFF  GUINEARICE_DIFF
# YEAR
# 1970-01-01   7.3187    0.311405          NaN              NaN
# 1971-01-01   7.3266    0.325180       0.0079         0.013775
# 1972-01-01   7.7956    0.339565       0.4690         0.014385
# 1973-01-01   9.3846    0.354580       1.5890         0.015015
# 1974-01-01  10.6647    0.370265       1.2801         0.015685

# %%
# now does it look stationary? 

air.plot(subplots=True)  #we can see the change in the difference now
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x000001C9D99C2C48>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000001C9D99B5588>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000001C9D99C2708>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000001C9D9A2E3C8>],
#       dtype=object)

# %%
# ACF plots
# the first row is missing, so skip that one..

fig = sm.graphics.tsa.plot_acf(air['AUSAIR_DIFF'][1:], lags=30) #correlations starts bouncing around, everything isnide lue area
#is not statsically significant --> changes is just bouncing around  #similarly to the rice differences
fig = sm.graphics.tsa.plot_acf(air['GUINEARICE_DIFF'][1:], lags=30)

# %%
# if we have to, we can also calculate a second difference
# don't go beyond 2

air['AUSAIR_2DIFF'] = air['AUSAIR_DIFF'] - air['AUSAIR_DIFF'].shift(1)  
air['GUINEARICE_2DIFF'] = air['GUINEARICE_DIFF'] - air['GUINEARICE_DIFF'].shift(1)  
air.head()
# Out:
#              AUSAIR  GUINEARICE  AUSAIR_DIFF  GUINEARICE_DIFF  AUSAIR_2DIFF  \
# YEAR
# 1970-01-01   7.3187    0.311405          NaN              NaN           NaN
# 1971-01-01   7.3266    0.325180       0.0079         0.013775           NaN
# 1972-01-01   7.7956    0.339565       0.4690         0.014385        0.4611
# 1973-01-01   9.3846    0.354580       1.5890         0.015015        1.1200
# 1974-01-01  10.6647    0.370265       1.2801         0.015685       -0.3089
#
#             GUINEARICE_2DIFF
# YEAR
# 1970-01-01               NaN
# 1971-01-01               NaN
# 1972-01-01           0.00061
# 1973-01-01           0.00063
# 1974-01-01           0.00067

# %%
air.plot(subplots=True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x000001C9D9D69448>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000001C9D9DA62C8>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000001C9D9D79B88>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000001C9D9E0B888>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000001C9D9E45148>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000001C9D9E78E88>],
#       dtype=object)

# %%
# ACF plots
# the first two rows are missing, so skip those..

fig = sm.graphics.tsa.plot_acf(air['AUSAIR_2DIFF'][2:], lags=30)
fig = sm.graphics.tsa.plot_acf(air['GUINEARICE_2DIFF'][2:], lags=30)

# %%
# now what if we estimate the same model on the differenced data

mod = smf.ols(formula='AUSAIR_DIFF ~ GUINEARICE_DIFF', data=air)
res = mod.fit()
print(res.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            AUSAIR_DIFF   R-squared:                       0.125
# Model:                            OLS   Adj. R-squared:                  0.102
# Method:                 Least Squares   F-statistic:                     5.295
# Date:                Tue, 07 Apr 2020   Prob (F-statistic):             0.0271
# Time:                        12:55:07   Log-Likelihood:                -70.079
# No. Observations:                  39   AIC:                             144.2
# Df Residuals:                      37   BIC:                             147.5
# Df Model:                           1
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# Intercept           0.5881      0.326      1.806      0.079      -0.072       1.248
# GUINEARICE_DIFF    16.6487      7.235      2.301      0.027       1.988      31.309
# ==============================================================================
# Omnibus:                        6.783   Durbin-Watson:                   1.733
# Prob(Omnibus):                  0.034   Jarque-Bera (JB):               10.436
# Skew:                          -0.123   Prob(JB):                      0.00542
# Kurtosis:                       5.522   Cond. No.                         30.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# now what if we estimate the same model on the second differenced data

mod = smf.ols(formula='AUSAIR_2DIFF ~ GUINEARICE_2DIFF', data=air)
res = mod.fit()
print(res.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           AUSAIR_2DIFF   R-squared:                       0.164
# Model:                            OLS   Adj. R-squared:                  0.141
# Method:                 Least Squares   F-statistic:                     7.088
# Date:                Tue, 07 Apr 2020   Prob (F-statistic):             0.0115
# Time:                        12:55:09   Log-Likelihood:                -79.187
# No. Observations:                  38   AIC:                             162.4
# Df Residuals:                      36   BIC:                             165.6
# Df Model:                           1
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# Intercept           -0.0150      0.324     -0.046      0.963      -0.673       0.642
# GUINEARICE_2DIFF    18.3687      6.900      2.662      0.012       4.376      32.362
# ==============================================================================
# Omnibus:                        6.128   Durbin-Watson:                   2.672
# Prob(Omnibus):                  0.047   Jarque-Bera (JB):                8.413
# Skew:                           0.116   Prob(JB):                       0.0149
# Kurtosis:                       5.293   Cond. No.                         21.3
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# ## Homework
#
# The data folder contains a time-series data set of ridership on the BART rail system from 2001 through 2015.  Estimate a regression model of the ridership (RIDERS) as a function of variables included in the data set.  Build as complete of a model as you can, but be sure you can explain it!

# %%
# %matplotlib inline

import pandas as pd
import seaborn as sns
import numpy as np
import statsmodels.api as sm
import statsmodels.formula.api as smf

BART = pd.read_csv('data/BARTEstimationFile.csv', parse_dates=['MONTH'], index_col='MONTH')
BART.head()
# Out:
#                  RIDERS  STATIONS  CASH_FARE_2010USD_BART  \
# MONTH
# 2001-01-01  321180.5238        39                3.262745
# 2001-02-01  334885.1053        39                3.249754
# 2001-03-01  340021.5455        39                3.242376
# 2001-04-01  333794.4286        39                3.229546
# 2001-05-01  333847.4545        39                3.215007
#
#             AVG_FARE_2010USD_BART           HH      HH_0VEH          POP  \
# MONTH
# 2001-01-01               2.555435  1452556.571  187359.1429  3870692.571
# 2001-02-01               2.545259  1452696.413  187278.4921  3870052.746
# 2001-03-01               2.539481  1452836.254  187197.8413  3869412.921
# 2001-04-01               2.529432  1452976.095  187117.1905  3868773.095
# 2001-05-01               2.518045  1453115.937  187036.5397  3868133.270
#
#                 WORKERS  MEDIAN_HHINC_2010USD  SERVMILES_E_BART  ...  \
# MONTH                                                            ...
# 2001-01-01  1924489.571           85841.07733       25527.10573  ...
# 2001-02-01  1923471.413           85401.59874       25527.10573  ...
# 2001-03-01  1922453.254           85110.28356       25527.10573  ...
# 2001-04-01  1921435.095           84676.45762       25527.10573  ...
# 2001-05-01  1920416.937           84198.65633       25527.10573  ...
#
#             EDHEALTH_EMP  LEISURE_EMP  OTHER_EMP  FUEL_PRICE_2010USD  \
# MONTH
# 2001-01-01      314779.0     179565.0  1317382.0            2.240335
# 2001-02-01      319473.0     181972.0  1321821.0            2.227694
# 2001-03-01      321266.0     184828.0  1331919.0            2.290702
# 2001-04-01      321919.0     185372.0  1308563.0            2.436951
# 2001-05-01      323980.0     188738.0  1302376.0            2.532738
#
#             FUEL_COST_2010USD  TOLL_BB_PK_2010USD  TOLL_BB_OP_2010USD  \
# MONTH
# 2001-01-01           0.101833            2.490645            2.490645
# 2001-02-01           0.101182            2.480728            2.480728
# 2001-03-01           0.103965            2.475096            2.475096
# 2001-04-01           0.110519            2.465302            2.465302
# 2001-05-01           0.114777            2.454204            2.454204
#
#             TOLL_BB_CARPOOL_2010USD  CASUAL_CARPOOL  BART_STRIKE
# MONTH
# 2001-01-01                      0.0               1            0
# 2001-02-01                      0.0               1            0
# 2001-03-01                      0.0               1            0
# 2001-04-01                      0.0               1            0
# 2001-05-01                      0.0               1            0
#
# [5 rows x 22 columns]

# %%
BART.plot()

# %%
#variables taken: HH_0VEH, WORKERS, TOTEMP, FUEL_PRICE_2010USD, FUEL_COST_2010USD

#creating first difference
BART['RIDERS_DIFF'] = BART['RIDERS'] - BART['RIDERS'].shift(12)
BART['CASH_FARE_2010USD_BART_DIFF'] = BART['CASH_FARE_2010USD_BART'] - BART['CASH_FARE_2010USD_BART'].shift(12)
BART['HH_DIFF'] = BART['HH'] - BART['HH'].shift(12) 
BART['HH_0VEH_DIFF'] = BART['HH_0VEH'] - BART['HH_0VEH'].shift(12)  
BART['WORKERS_DIFF'] = BART['WORKERS'] - BART['WORKERS'].shift(12) 
BART['MEDIAN_HHINC_2010USD_DIFF'] = BART['MEDIAN_HHINC_2010USD'] - BART['MEDIAN_HHINC_2010USD'].shift(12) 
BART['SERVMILES_E_BART_DIFF'] = BART['SERVMILES_E_BART'] - BART['SERVMILES_E_BART'].shift(12) 
BART['TOTEMP_DIFF'] = BART['TOTEMP'] - BART['TOTEMP'].shift(12)  
BART['FUEL_PRICE_2010USD_DIFF'] = BART['FUEL_PRICE_2010USD'] - BART['FUEL_PRICE_2010USD'].shift(12)  
BART['FUEL_COST_2010USD_DIFF'] = BART['FUEL_COST_2010USD'] - BART['FUEL_COST_2010USD'].shift(12)  
BART['BART_STRIKE_DIFF'] = BART['BART_STRIKE'] - BART['BART_STRIKE'].shift(12)  

#creating second difference
BART['RIDERS_DIFF2'] = BART['RIDERS_DIFF'] - BART['RIDERS_DIFF'].shift(12)
BART['CASH_FARE_2010USD_BART_DIFF2'] = BART['CASH_FARE_2010USD_BART_DIFF'] - BART['CASH_FARE_2010USD_BART_DIFF'].shift(12)
BART['HH_DIFF2'] = BART['HH_DIFF'] - BART['HH_DIFF'].shift(12) 
BART['HH_0VEH_DIFF2'] = BART['HH_0VEH_DIFF'] - BART['HH_0VEH_DIFF'].shift(12) 
BART['WORKERS_DIFF2'] = BART['WORKERS_DIFF'] - BART['WORKERS_DIFF'].shift(12) 
BART['MEDIAN_HHINC_2010USD_DIFF2'] = BART['MEDIAN_HHINC_2010USD_DIFF'] - BART['MEDIAN_HHINC_2010USD_DIFF'].shift(12) 
BART['SERVMILES_E_BART_DIFF2'] = BART['SERVMILES_E_BART_DIFF'] - BART['SERVMILES_E_BART_DIFF'].shift(12) 
BART['TOTEMP_DIFF2'] = BART['TOTEMP_DIFF'] - BART['TOTEMP_DIFF'].shift(12) 
BART['FUEL_PRICE_2010USD_DIFF2'] = BART['FUEL_PRICE_2010USD_DIFF'] - BART['FUEL_PRICE_2010USD_DIFF'].shift(12) 
BART['FUEL_COST_2010USD_DIFF2'] = BART['FUEL_COST_2010USD_DIFF'] - BART['FUEL_COST_2010USD_DIFF'].shift(12) 
BART['BART_STRIKE_DIFF2'] = BART['BART_STRIKE_DIFF'] - BART['BART_STRIKE_DIFF'].shift(12)  

BART.head()
# Out:
#                  RIDERS  STATIONS  CASH_FARE_2010USD_BART  \
# MONTH
# 2001-01-01  321180.5238        39                3.262745
# 2001-02-01  334885.1053        39                3.249754
# 2001-03-01  340021.5455        39                3.242376
# 2001-04-01  333794.4286        39                3.229546
# 2001-05-01  333847.4545        39                3.215007
#
#             AVG_FARE_2010USD_BART           HH      HH_0VEH          POP  \
# MONTH
# 2001-01-01               2.555435  1452556.571  187359.1429  3870692.571
# 2001-02-01               2.545259  1452696.413  187278.4921  3870052.746
# 2001-03-01               2.539481  1452836.254  187197.8413  3869412.921
# 2001-04-01               2.529432  1452976.095  187117.1905  3868773.095
# 2001-05-01               2.518045  1453115.937  187036.5397  3868133.270
#
#                 WORKERS  MEDIAN_HHINC_2010USD  SERVMILES_E_BART  ...  \
# MONTH                                                            ...
# 2001-01-01  1924489.571           85841.07733       25527.10573  ...
# 2001-02-01  1923471.413           85401.59874       25527.10573  ...
# 2001-03-01  1922453.254           85110.28356       25527.10573  ...
# 2001-04-01  1921435.095           84676.45762       25527.10573  ...
# 2001-05-01  1920416.937           84198.65633       25527.10573  ...
#
#             CASH_FARE_2010USD_BART_DIFF2  HH_DIFF2  HH_0VEH_DIFF2  \
# MONTH
# 2001-01-01                           NaN       NaN            NaN
# 2001-02-01                           NaN       NaN            NaN
# 2001-03-01                           NaN       NaN            NaN
# 2001-04-01                           NaN       NaN            NaN
# 2001-05-01                           NaN       NaN            NaN
#
#             WORKERS_DIFF2  MEDIAN_HHINC_2010USD_DIFF2  SERVMILES_E_BART_DIFF2  \
# MONTH
# 2001-01-01            NaN                         NaN                     NaN
# 2001-02-01            NaN                         NaN                     NaN
# 2001-03-01            NaN                         NaN                     NaN
# 2001-04-01            NaN                         NaN                     NaN
# 2001-05-01            NaN                         NaN                     NaN
#
#             TOTEMP_DIFF2  FUEL_PRICE_2010USD_DIFF2  FUEL_COST_2010USD_DIFF2  \
# MONTH
# 2001-01-01           NaN                       NaN                      NaN
# 2001-02-01           NaN                       NaN                      NaN
# 2001-03-01           NaN                       NaN                      NaN
# 2001-04-01           NaN                       NaN                      NaN
# 2001-05-01           NaN                       NaN                      NaN
#
#             BART_STRIKE_DIFF2
# MONTH
# 2001-01-01                NaN
# 2001-02-01                NaN
# 2001-03-01                NaN
# 2001-04-01                NaN
# 2001-05-01                NaN
#
# [5 rows x 44 columns]

# %%
#if we estimate the same model on the differenced data 1

mod1 = smf.ols(formula='RIDERS_DIFF ~ CASH_FARE_2010USD_BART_DIFF+HH_DIFF+HH_0VEH_DIFF+WORKERS_DIFF+MEDIAN_HHINC_2010USD_DIFF+SERVMILES_E_BART_DIFF+TOTEMP_DIFF+FUEL_PRICE_2010USD_DIFF+FUEL_COST_2010USD_DIFF', data=BART)
res1 = mod1.fit()
print(res1.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            RIDERS_DIFF   R-squared:                       0.614
# Model:                            OLS   Adj. R-squared:                  0.590
# Method:                 Least Squares   F-statistic:                     25.82
# Date:                Thu, 09 Apr 2020   Prob (F-statistic):           3.82e-26
# Time:                        12:45:04   Log-Likelihood:                -1694.2
# No. Observations:                 156   AIC:                             3408.
# Df Residuals:                     146   BIC:                             3439.
# Df Model:                           9
# Covariance Type:            nonrobust
# ===============================================================================================
#                                   coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------
# Intercept                   -2218.0356   3190.396     -0.695      0.488   -8523.360    4087.289
# CASH_FARE_2010USD_BART_DIFF  1.265e+04   1.07e+04      1.182      0.239   -8496.554    3.38e+04
# HH_DIFF                        -0.4711      0.171     -2.750      0.007      -0.810      -0.133
# HH_0VEH_DIFF                    1.8869      0.378      4.998      0.000       1.141       2.633
# WORKERS_DIFF                    0.2620      0.106      2.473      0.015       0.053       0.471
# MEDIAN_HHINC_2010USD_DIFF      -4.3609      1.131     -3.856      0.000      -6.596      -2.126
# SERVMILES_E_BART_DIFF           5.4486      1.497      3.640      0.000       2.490       8.407
# TOTEMP_DIFF                     0.2359      0.044      5.372      0.000       0.149       0.323
# FUEL_PRICE_2010USD_DIFF     -1.053e+04   3.86e+04     -0.272      0.786   -8.69e+04    6.59e+04
# FUEL_COST_2010USD_DIFF       1.888e+05   9.01e+05      0.209      0.834   -1.59e+06    1.97e+06
# ==============================================================================
# Omnibus:                       40.810   Durbin-Watson:                   1.874
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              611.148
# Skew:                           0.255   Prob(JB):                    1.95e-133
# Kurtosis:                      12.683   Cond. No.                     5.93e+07
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 5.93e+07. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
#if we estimate the same model on the differenced data 1

mod1 = smf.ols(formula='RIDERS_DIFF ~ BART_STRIKE_DIFF+CASH_FARE_2010USD_BART_DIFF+HH_DIFF+HH_0VEH_DIFF+WORKERS_DIFF+MEDIAN_HHINC_2010USD_DIFF+SERVMILES_E_BART_DIFF+TOTEMP_DIFF+FUEL_PRICE_2010USD_DIFF+FUEL_COST_2010USD_DIFF', data=BART)
res1 = mod1.fit()
print(res1.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            RIDERS_DIFF   R-squared:                       0.870
# Model:                            OLS   Adj. R-squared:                  0.861
# Method:                 Least Squares   F-statistic:                     96.65
# Date:                Thu, 09 Apr 2020   Prob (F-statistic):           5.65e-59
# Time:                        12:44:07   Log-Likelihood:                -1609.6
# No. Observations:                 156   AIC:                             3241.
# Df Residuals:                     145   BIC:                             3275.
# Df Model:                          10
# Covariance Type:            nonrobust
# ===============================================================================================
#                                   coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------
# Intercept                     543.6410   1868.719      0.291      0.772   -3149.806    4237.088
# BART_STRIKE_DIFF            -7.062e+04   4191.899    -16.848      0.000   -7.89e+04   -6.23e+04
# CASH_FARE_2010USD_BART_DIFF  2466.3567   6271.321      0.393      0.695   -9928.656    1.49e+04
# HH_DIFF                         0.0644      0.105      0.614      0.540      -0.143       0.272
# HH_0VEH_DIFF                    0.2824      0.240      1.177      0.241      -0.192       0.757
# WORKERS_DIFF                    0.0417      0.063      0.660      0.510      -0.083       0.167
# MEDIAN_HHINC_2010USD_DIFF      -2.4923      0.669     -3.725      0.000      -3.815      -1.170
# SERVMILES_E_BART_DIFF           4.7562      0.874      5.440      0.000       3.028       6.484
# TOTEMP_DIFF                     0.2577      0.026     10.042      0.000       0.207       0.308
# FUEL_PRICE_2010USD_DIFF      8.221e+04   2.32e+04      3.542      0.001    3.63e+04    1.28e+05
# FUEL_COST_2010USD_DIFF      -1.936e+06   5.41e+05     -3.581      0.000      -3e+06   -8.68e+05
# ==============================================================================
# Omnibus:                        0.344   Durbin-Watson:                   1.001
# Prob(Omnibus):                  0.842   Jarque-Bera (JB):                0.260
# Skew:                          -0.100   Prob(JB):                        0.878
# Kurtosis:                       2.994   Cond. No.                     6.10e+07
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 6.1e+07. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
#if we estimate the same model on the differenced data 2

mod1 = smf.ols(formula='RIDERS_DIFF2 ~ CASH_FARE_2010USD_BART_DIFF2+HH_DIFF2+HH_0VEH_DIFF2+WORKERS_DIFF2+MEDIAN_HHINC_2010USD_DIFF2+SERVMILES_E_BART_DIFF2+TOTEMP_DIFF2+FUEL_PRICE_2010USD_DIFF2+FUEL_COST_2010USD_DIFF2', data=BART)
res1 = mod1.fit()
print(res1.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           RIDERS_DIFF2   R-squared:                       0.469
# Model:                            OLS   Adj. R-squared:                  0.433
# Method:                 Least Squares   F-statistic:                     13.14
# Date:                Thu, 09 Apr 2020   Prob (F-statistic):           7.01e-15
# Time:                        12:45:16   Log-Likelihood:                -1633.7
# No. Observations:                 144   AIC:                             3287.
# Df Residuals:                     134   BIC:                             3317.
# Df Model:                           9
# Covariance Type:            nonrobust
# ================================================================================================
#                                    coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# Intercept                     2204.7765   1960.108      1.125      0.263   -1671.976    6081.529
# CASH_FARE_2010USD_BART_DIFF2  3116.8327   1.24e+04      0.252      0.802   -2.14e+04    2.76e+04
# HH_DIFF2                        -0.4992      0.257     -1.943      0.054      -1.007       0.009
# HH_0VEH_DIFF2                    1.6342      0.374      4.368      0.000       0.894       2.374
# WORKERS_DIFF2                    0.1547      0.132      1.169      0.244      -0.107       0.416
# MEDIAN_HHINC_2010USD_DIFF2      -4.8221      1.350     -3.571      0.000      -7.493      -2.152
# SERVMILES_E_BART_DIFF2           7.7052      1.628      4.734      0.000       4.486      10.924
# TOTEMP_DIFF2                     0.2089      0.059      3.568      0.001       0.093       0.325
# FUEL_PRICE_2010USD_DIFF2      5.102e+04   5.46e+04      0.934      0.352   -5.71e+04    1.59e+05
# FUEL_COST_2010USD_DIFF2      -1.244e+06   1.26e+06     -0.989      0.324   -3.73e+06    1.24e+06
# ==============================================================================
# Omnibus:                      106.609   Durbin-Watson:                   1.995
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1573.093
# Skew:                           2.344   Prob(JB):                         0.00
# Kurtosis:                      18.499   Cond. No.                     4.50e+07
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 4.5e+07. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
#if we estimate the same model on the differenced data 2

mod1 = smf.ols(formula='RIDERS_DIFF2 ~ BART_STRIKE_DIFF2+CASH_FARE_2010USD_BART_DIFF2+HH_DIFF2+HH_0VEH_DIFF2+WORKERS_DIFF2+MEDIAN_HHINC_2010USD_DIFF2+SERVMILES_E_BART_DIFF2+TOTEMP_DIFF2+FUEL_PRICE_2010USD_DIFF2+FUEL_COST_2010USD_DIFF2', data=BART)
res1 = mod1.fit()
print(res1.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           RIDERS_DIFF2   R-squared:                       0.861
# Model:                            OLS   Adj. R-squared:                  0.851
# Method:                 Least Squares   F-statistic:                     82.37
# Date:                Thu, 09 Apr 2020   Prob (F-statistic):           5.42e-52
# Time:                        12:44:14   Log-Likelihood:                -1537.2
# No. Observations:                 144   AIC:                             3096.
# Df Residuals:                     133   BIC:                             3129.
# Df Model:                          10
# Covariance Type:            nonrobust
# ================================================================================================
#                                    coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# Intercept                     2054.5605   1006.478      2.041      0.043      63.786    4045.335
# BART_STRIKE_DIFF2            -7.431e+04   3836.007    -19.372      0.000   -8.19e+04   -6.67e+04
# CASH_FARE_2010USD_BART_DIFF2 -6446.5136   6373.308     -1.011      0.314   -1.91e+04    6159.642
# HH_DIFF2                         0.0345      0.135      0.256      0.798      -0.232       0.301
# HH_0VEH_DIFF2                   -0.0280      0.210     -0.133      0.894      -0.444       0.388
# WORKERS_DIFF2                   -0.0785      0.069     -1.138      0.257      -0.215       0.058
# MEDIAN_HHINC_2010USD_DIFF2      -2.9281      0.700     -4.182      0.000      -4.313      -1.543
# SERVMILES_E_BART_DIFF2           6.9342      0.837      8.288      0.000       5.279       8.589
# TOTEMP_DIFF2                     0.2389      0.030      7.933      0.000       0.179       0.298
# FUEL_PRICE_2010USD_DIFF2      1.409e+05   2.84e+04      4.953      0.000    8.46e+04    1.97e+05
# FUEL_COST_2010USD_DIFF2      -3.294e+06   6.54e+05     -5.033      0.000   -4.59e+06      -2e+06
# ==============================================================================
# Omnibus:                        1.160   Durbin-Watson:                   1.388
# Prob(Omnibus):                  0.560   Jarque-Bera (JB):                1.262
# Skew:                           0.190   Prob(JB):                        0.532
# Kurtosis:                       2.742   Cond. No.                     4.56e+07
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 4.56e+07. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
#significance with HH_0VEH, WORKERS_DIFF, SERVMILES_E_BART_DIF, TOTEMP_DIFF
